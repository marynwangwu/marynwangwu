# %% [markdown]
# <a href="https://colab.research.google.com/github/marynwangwu/marynwangwu/blob/main/AutoTrain_Llama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 🤗 AutoTrain LLM
#@markdown In order to use this colab
#@markdown - upload train.csv to a folder named `data/`
#@markdown - train.csv must contain a `text` column
#@markdown - choose a project name if you wish
#@markdown - change model if you wish, you can use most of the text-generation models from Hugging Face Hub
#@markdown - add huggingface information (token and repo_id) if you wish to push trained model to huggingface hub
#@markdown - update hyperparameters if you wish
#@markdown - click `Runtime > Run all` or run each cell individually

import os
# !pip install -U autotrain-advanced > install_logs.txt
# !autotrain setup --colab > setup_logs.txt

# %%
import os

# %%
#@markdown ---
#@markdown #### Project Config
#@markdown Note: if you are using a restricted/private model, you need to enter your Hugging Face token in the next step.
project_name = 'my_autotrain_llm' # @param {type:"string"}
model_name = 'TinyPixel/Llama-2-7B-bf16-sharded' # @param {type:"string"}

#@markdown ---
#@markdown #### Push to Hub?
#@markdown Use these only if you want to push your trained model to a private repo in your Hugging Face Account
#@markdown If you dont use these, the model will be saved in Google Colab and you are required to download it manually.
#@markdown Please enter your Hugging Face write token. The trained model will be saved to your Hugging Face account.
#@markdown You can find your token here: https://huggingface.co/settings/tokens
push_to_hub = True # @param ["False", "True"] {type:"raw"}
hf_token = "" #@param {type:"string"}
repo_id = "" #@param {type:"string"}

#@markdown ---
#@markdown #### Hyperparameters
learning_rate = 2e-4 # @param {type:"number"}
num_epochs = 5 #@param {type:"number"}
batch_size = 1 # @param {type:"slider", min:1, max:32, step:1}
block_size = 1024 # @param {type:"number"}
trainer = "sft" # @param ["default", "sft"] {type:"raw"}
warmup_ratio = 0.1 # @param {type:"number"}
weight_decay = 0.01 # @param {type:"number"}
gradient_accumulation = 4 # @param {type:"number"}
use_fp16 = False # @param ["False", "True"] {type:"raw"}
use_peft = True # @param ["False", "True"] {type:"raw"}
use_int4 = True # @param ["False", "True"] {type:"raw"}
lora_r = 16 #@param {type:"number"}
lora_alpha = 32 #@param {type:"number"}
lora_dropout = 0.05 #@param {type:"number"}

os.environ["PROJECT_NAME"] = project_name
os.environ["MODEL_NAME"] = model_name
os.environ["PUSH_TO_HUB"] = str(push_to_hub)
os.environ["HF_TOKEN"] = hf_token
os.environ["REPO_ID"] = repo_id
os.environ["LEARNING_RATE"] = str(learning_rate)
os.environ["NUM_EPOCHS"] = str(num_epochs)
os.environ["BATCH_SIZE"] = str(batch_size)
os.environ["BLOCK_SIZE"] = str(block_size)
os.environ["WARMUP_RATIO"] = str(warmup_ratio)
os.environ["WEIGHT_DECAY"] = str(weight_decay)
os.environ["GRADIENT_ACCUMULATION"] = str(gradient_accumulation)
os.environ["USE_FP16"] = str(use_fp16)
os.environ["USE_PEFT"] = str(use_peft)
os.environ["USE_INT4"] = str(use_int4)
os.environ["LORA_R"] = str(lora_r)
os.environ["LORA_ALPHA"] = str(lora_alpha)
os.environ["LORA_DROPOUT"] = str(lora_dropout)

# %%
# !pip install autotrain-advanced
# !autotrain setup --update-torch
# !autotrain llm
# Out:
# Collecting autotrain-advanced
#   Downloading autotrain_advanced-0.6.51-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: albumentations==1.3.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.3.1)
# Collecting codecarbon==2.2.3 (from autotrain-advanced)
#   Downloading codecarbon-2.2.3-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 11.7 MB/s eta 0:00:00
# Collecting datasets[vision]~=2.14.0 (from autotrain-advanced)
#   Downloading datasets-2.14.7-py3-none-any.whl (520 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.4/520.4 kB 28.4 MB/s eta 0:00:00
# Collecting evaluate==0.3.0 (from autotrain-advanced)
#   Downloading evaluate-0.3.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 10.5 MB/s eta 0:00:00
# Collecting ipadic==1.0.0 (from autotrain-advanced)
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 95.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jiwer==3.0.2 (from autotrain-advanced)
#   Downloading jiwer-3.0.2-py3-none-any.whl (21 kB)
# Collecting joblib==1.3.1 (from autotrain-advanced)
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 39.9 MB/s eta 0:00:00
# Collecting loguru==0.7.0 (from autotrain-advanced)
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.5.3)
# Requirement already satisfied: nltk==3.8.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (3.8.1)
# Collecting optuna==3.3.0 (from autotrain-advanced)
#   Downloading optuna-3.3.0-py3-none-any.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 49.1 MB/s eta 0:00:00
# Collecting Pillow==10.0.0 (from autotrain-advanced)
#   Downloading Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 110.0 MB/s eta 0:00:00
# Collecting protobuf==4.23.4 (from autotrain-advanced)
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 18.2 MB/s eta 0:00:00
# Collecting sacremoses==0.0.53 (from autotrain-advanced)
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 42.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn==1.3.0 (from autotrain-advanced)
#   Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 35.0 MB/s eta 0:00:00
# Collecting sentencepiece==0.1.99 (from autotrain-advanced)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.4 MB/s eta 0:00:00
# Collecting tqdm==4.65.0 (from autotrain-advanced)
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.5 MB/s eta 0:00:00
# Collecting werkzeug==2.3.6 (from autotrain-advanced)
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 26.7 MB/s eta 0:00:00
# Collecting xgboost==1.7.6 (from autotrain-advanced)
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.19.4)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.31.0)
# Collecting einops==0.6.1 (from autotrain-advanced)
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.7 MB/s eta 0:00:00
# Collecting invisible-watermark==0.2.0 (from autotrain-advanced)
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 96.4 MB/s eta 0:00:00
# Collecting packaging==23.1 (from autotrain-advanced)
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.14.1)
# Collecting peft==0.6.2 (from autotrain-advanced)
#   Downloading peft-0.6.2-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.7/174.7 kB 24.8 MB/s eta 0:00:00
# Collecting trl==0.7.4 (from autotrain-advanced)
#   Downloading trl-0.7.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 19.2 MB/s eta 0:00:00
# Collecting tiktoken==0.5.1 (from autotrain-advanced)
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 95.0 MB/s eta 0:00:00
# Requirement already satisfied: transformers==4.35.2 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (4.35.2)
# Collecting accelerate==0.24.0 (from autotrain-advanced)
#   Downloading accelerate-0.24.0-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 26.8 MB/s eta 0:00:00
# Collecting diffusers==0.21.4 (from autotrain-advanced)
#   Downloading diffusers-0.21.4-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 91.9 MB/s eta 0:00:00
# Collecting bitsandbytes==0.41.0 (from autotrain-advanced)
#   Downloading bitsandbytes-0.41.0-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.2 MB/s eta 0:00:00
# Collecting rouge-score==0.1.2 (from autotrain-advanced)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting py7zr==0.20.6 (from autotrain-advanced)
#   Downloading py7zr-0.20.6-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 kB 10.2 MB/s eta 0:00:00
# Collecting fastapi==0.104.1 (from autotrain-advanced)
#   Downloading fastapi-0.104.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 12.6 MB/s eta 0:00:00
# Collecting uvicorn==0.22.0 (from autotrain-advanced)
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.2 MB/s eta 0:00:00
# Collecting python-multipart==0.0.6 (from autotrain-advanced)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.4 MB/s eta 0:00:00
# Collecting gradio==3.41.0 (from autotrain-advanced)
#   Downloading gradio-3.41.0-py3-none-any.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 78.5 MB/s eta 0:00:00
# Collecting pydantic==2.4.2 (from autotrain-advanced)
#   Downloading pydantic-2.4.2-py3-none-any.whl (395 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.8/395.8 kB 39.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.24.0->autotrain-advanced) (1.23.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.24.0->autotrain-advanced) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.24.0->autotrain-advanced) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.24.0->autotrain-advanced) (2.1.0+cu118)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (1.11.4)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (0.19.3)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (4.8.1.78)
# Collecting arrow (from codecarbon==2.2.3->autotrain-advanced)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.0 MB/s eta 0:00:00
# Collecting pynvml (from codecarbon==2.2.3->autotrain-advanced)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (9.0.0)
# Collecting fuzzywuzzy (from codecarbon==2.2.3->autotrain-advanced)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (3.13.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (6.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (2023.6.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (0.4.1)
# Collecting datasets>=2.0.0 (from evaluate==0.3.0->autotrain-advanced)
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 52.6 MB/s eta 0:00:00
# Collecting dill (from evaluate==0.3.0->autotrain-advanced)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate==0.3.0->autotrain-advanced) (3.4.1)
# Collecting multiprocess (from evaluate==0.3.0->autotrain-advanced)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.3.0->autotrain-advanced) (2023.6.0)
# Collecting responses<0.19 (from evaluate==0.3.0->autotrain-advanced)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.104.1->autotrain-advanced) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi==0.104.1->autotrain-advanced)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.7 MB/s eta 0:00:00
# Collecting typing-extensions>=4.8.0 (from fastapi==0.104.1->autotrain-advanced)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (4.2.2)
# Collecting ffmpy (from gradio==3.41.0->autotrain-advanced)
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.5.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading gradio_client-0.5.0-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 25.6 MB/s eta 0:00:00
# Collecting httpx (from gradio==3.41.0->autotrain-advanced)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (3.7.1)
# Collecting orjson~=3.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 10.5 MB/s eta 0:00:00
# Collecting pydub (from gradio==3.41.0->autotrain-advanced)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting semantic-version~=2.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting websockets<12.0,>=10.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0->autotrain-advanced) (1.5.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0->autotrain-advanced) (4.8.0.76)
# Collecting rapidfuzz==2.13.7 (from jiwer==3.0.2->autotrain-advanced)
#   Downloading rapidfuzz-2.13.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 95.7 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna==3.3.0->autotrain-advanced)
#   Downloading alembic-1.13.0-py3-none-any.whl (230 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.6/230.6 kB 28.5 MB/s eta 0:00:00
# Collecting cmaes>=0.10.0 (from optuna==3.3.0->autotrain-advanced)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna==3.3.0->autotrain-advanced)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna==3.3.0->autotrain-advanced) (2.0.23)
# Collecting texttable (from py7zr==0.20.6->autotrain-advanced)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.6.6 (from py7zr==0.20.6->autotrain-advanced)
#   Downloading pycryptodomex-3.19.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 107.6 MB/s eta 0:00:00
# Collecting pyzstd>=0.14.4 (from py7zr==0.20.6->autotrain-advanced)
#   Downloading pyzstd-0.15.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 45.5 MB/s eta 0:00:00
# Collecting pyppmd<1.1.0,>=0.18.1 (from py7zr==0.20.6->autotrain-advanced)
#   Downloading pyppmd-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 18.6 MB/s eta 0:00:00
# Collecting pybcj>=0.6.0 (from py7zr==0.20.6->autotrain-advanced)
#   Downloading pybcj-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 7.0 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr==0.20.6->autotrain-advanced)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting brotli>=1.0.9 (from py7zr==0.20.6->autotrain-advanced)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 103.0 MB/s eta 0:00:00
# Collecting inflate64>=0.3.1 (from py7zr==0.20.6->autotrain-advanced)
#   Downloading inflate64-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 12.4 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic==2.4.2->autotrain-advanced)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.10.1 (from pydantic==2.4.2->autotrain-advanced)
#   Downloading pydantic_core-2.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 92.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (2023.11.17)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->autotrain-advanced) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->autotrain-advanced) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.0->autotrain-advanced) (3.2.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2->autotrain-advanced) (0.15.0)
# Collecting tyro>=0.5.11 (from trl==0.7.4->autotrain-advanced)
#   Downloading tyro-0.6.0-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 14.8 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn==0.22.0->autotrain-advanced)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.14.0->autotrain-advanced) (9.0.0)
# Collecting pyarrow-hotfix (from datasets[vision]~=2.14.0->autotrain-advanced)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.14.0->autotrain-advanced) (3.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->autotrain-advanced) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->autotrain-advanced) (2023.3.post1)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (3.5.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (0.7.2)
# Collecting Mako (from alembic>=1.5.0->optuna==3.3.0->autotrain-advanced)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.12.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi==0.104.1->autotrain-advanced) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi==0.104.1->autotrain-advanced) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->autotrain-advanced) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (3.1.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (2023.9.26)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna==3.3.0->autotrain-advanced) (3.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.24.0->autotrain-advanced) (1.12)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.24.0->autotrain-advanced) (2.1.0)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl==0.7.4->autotrain-advanced)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl==0.7.4->autotrain-advanced)
#   Downloading shtab-1.6.5-py3-none-any.whl (13 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow->codecarbon==2.2.3->autotrain-advanced)
#   Downloading types_python_dateutil-2.8.19.14-py3-none-any.whl (9.4 kB)
# Collecting httpcore==1.* (from httpx->gradio==3.41.0->autotrain-advanced)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.21.4->autotrain-advanced) (3.17.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.13.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->autotrain-advanced) (3.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (2.16.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.24.0->autotrain-advanced) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (0.1.2)
# Building wheels for collected packages: ipadic, rouge-score, sacremoses, ffmpy
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556704 sha256=12fec384e8d2b89b1ebaad3df19830b7a328c885c775ab4279f32ba86f6a5ba8
#   Stored in directory: /root/.cache/pip/wheels/5b/ea/e3/2f6e0860a327daba3b030853fce4483ed37468bbf1101c59c3
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=25d7fd3c2400f679dc4e87bcd8fc073952f8338fecb020d304aa4f7a866fc872
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895239 sha256=059f8150f54e55706bba57dc989dc12e1e23d66c7c8b4d7029863acdbfa02dbb
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=6842aeb92fa2b8cb135ae6a756c637c3ce7d816b29701ce06f97ce2a8fb6556d
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built ipadic rouge-score sacremoses ffmpy
# Installing collected packages: types-python-dateutil, texttable, sentencepiece, pydub, ipadic, fuzzywuzzy, ffmpy, brotli, bitsandbytes, werkzeug, websockets, typing-extensions, tqdm, shtab, semantic-version, rapidfuzz, pyzstd, python-multipart, pyppmd, pynvml, pycryptodomex, pybcj, pyarrow-hotfix, protobuf, Pillow, packaging, orjson, multivolumefile, Mako, loguru, joblib, inflate64, h11, einops, docstring-parser, dill, colorlog, cmaes, annotated-types, aiofiles, xgboost, uvicorn, tiktoken, starlette, scikit-learn, sacremoses, responses, pydantic-core, py7zr, multiprocess, jiwer, httpcore, arrow, tyro, rouge-score, pydantic, invisible-watermark, httpx, diffusers, codecarbon, alembic, accelerate, optuna, gradio-client, fastapi, datasets, trl, peft, gradio, evaluate, autotrain-advanced
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.1
#     Uninstalling Werkzeug-3.0.1:
#       Successfully uninstalled Werkzeug-3.0.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.2
#     Uninstalling xgboost-2.0.2:
#       Successfully uninstalled xgboost-2.0.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed Mako-1.3.0 Pillow-10.0.0 accelerate-0.24.0 aiofiles-23.2.1 alembic-1.13.0 annotated-types-0.6.0 arrow-1.3.0 autotrain-advanced-0.6.51 bitsandbytes-0.41.0 brotli-1.1.0 cmaes-0.10.0 codecarbon-2.2.3 colorlog-6.8.0 datasets-2.14.7 diffusers-0.21.4 dill-0.3.7 docstring-parser-0.15 einops-0.6.1 evaluate-0.3.0 fastapi-0.104.1 ffmpy-0.3.1 fuzzywuzzy-0.18.0 gradio-3.41.0 gradio-client-0.5.0 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 inflate64-1.0.0 invisible-watermark-0.2.0 ipadic-1.0.0 jiwer-3.0.2 joblib-1.3.1 loguru-0.7.0 multiprocess-0.70.15 multivolumefile-0.2.3 optuna-3.3.0 orjson-3.9.10 packaging-23.1 peft-0.6.2 protobuf-4.23.4 py7zr-0.20.6 pyarrow-hotfix-0.6 pybcj-1.0.2 pycryptodomex-3.19.0 pydantic-2.4.2 pydantic-core-2.10.1 pydub-0.25.1 pynvml-11.5.0 pyppmd-1.0.0 python-multipart-0.0.6 pyzstd-0.15.9 rapidfuzz-2.13.7 responses-0.18.0 rouge-score-0.1.2 sacremoses-0.0.53 scikit-learn-1.3.0 semantic-version-2.10.0 sentencepiece-0.1.99 shtab-1.6.5 starlette-0.27.0 texttable-1.7.0 tiktoken-0.5.1 tqdm-4.65.0 trl-0.7.4 types-python-dateutil-2.8.19.14 typing-extensions-4.8.0 tyro-0.6.0 uvicorn-0.22.0 websockets-11.0.3 werkzeug-2.3.6 xgboost-1.7.6
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers
# > INFO    Installing latest PyTorch
# > INFO    Successfully installed latest PyTorch
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# > INFO    Running LLM
# > INFO    Params: Namespace(version=False, train=False, deploy=False, inference=False, data_path=None, train_split='train', valid_split=None, text_column='text', rejected_text_column='rejected', prompt_text_column='prompt', model=None, model_ref=None, learning_rate=3e-05, num_train_epochs=1, train_batch_size=2, warmup_ratio=0.1, gradient_accumulation_steps=1, optimizer='adamw_torch', scheduler='linear', weight_decay=0.0, max_grad_norm=1.0, seed=42, add_eos_token=False, block_size=-1, use_peft=False, lora_r=16, lora_alpha=32, lora_dropout=0.05, logging_steps=-1, project_name=None, evaluation_strategy='epoch', save_total_limit=1, save_strategy='epoch', auto_find_batch_size=False, fp16=False, push_to_hub=False, use_int8=False, model_max_length=1024, repo_id=None, use_int4=False, trainer='default', target_modules=None, merge_adapter=False, token=None, backend='default', username=None, use_flash_attention_2=False, log='none', disable_gradient_checkpointing=False, dpo_beta=0.1, func=<function run_llm_command_factory at 0x7f986d145fc0>)

# %%
from datasets import load_dataset
import pandas as pd

datasets = load_dataset("valurank/News_headlines")

# Convert multiple splits to Pandas DataFrames
df_train = datasets["train"].to_pandas()
df_val = datasets["validation"].to_pandas()

# Concatenate DataFrames
df_combined = pd.concat([df_train, df_val], ignore_index=True)

df_combined = df_combined.iloc[:500,:]

# Display the combined DataFrame
display(df_combined)

# Create a column name "text" for the promp template, its better to name the column 'text'
format_text = "You summarize below news article into concise, descriptive news headline that captures the details of the article.\n### article: {}\n### headline: {}"
df_combined['text'] = df_combined.apply(lambda x: format_text.format(x['article'], x['headline']), axis=1)
# Out:
# Downloading readme:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/46.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.33M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
#                                                article  \
# 0    The logo of cryptocurrency exchange Binance di...
# 1    Police officers, some in riot gear, guard a gr...
# 2    A woman walks past a row of cash machines outs...
# 3    The Amazon logo is seen outside its JFK8 distr...
# 4    An unexploded shell from a multiple rocket lau...
# ..                                                 ...
# 495  The Arleigh Burke-class guided-missile destroy...
# 496  The Iranian flag waves in front of the Interna...
# 497  Livestreaming sessions by Chinese livestreamer...
# 498  Register now for FREE unlimited access to Reut...
# 499  A Toyota Motor Corp. logo is seen on a car at ...
#
#                                               headline
# 0    Binance pauses bitcoin withdrawals due to a 's...
# 1    White nationalist group members face riot-plan...
# 2    Lloyds to give staff 1,000 pounds to ease cost...
# 3    Amazon offers to share data, boost rivals to d...
# 4    Both sides using heavier weapons in war in Ukr...
# ..                                                 ...
# 495  U.S. rebuffs China by calling Taiwan Strait an...
# 496  U.S. awaits 'constructive' response from Tehra...
# 497  China cyberspace regulator's revised rules gov...
# 498  Happy the elephant is denied personhood, to st...
# 499  Toyota, slow to move to EVs, says it offers ch...
#
# [500 rows x 2 columns]
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
# Specify the directory path
directory_path = 'data/'

# Create the directory if it does not exist
if not os.path.exists(directory_path):
    os.makedirs(directory_path)

# Save the DataFrame to CSV
df_combined.to_csv(os.path.join(directory_path, 'formatted_headline_data.csv'), index=False)

# %%
# !autotrain llm \
--train \
--model ${MODEL_NAME} \
--project-name ${PROJECT_NAME} \
--data-path data/ \
--text-column text \
--lr ${LEARNING_RATE} \
--batch-size ${BATCH_SIZE} \
--epochs ${NUM_EPOCHS} \
--block-size ${BLOCK_SIZE} \
--warmup-ratio ${WARMUP_RATIO} \
--lora-r ${LORA_R} \
--lora-alpha ${LORA_ALPHA} \
--lora-dropout ${LORA_DROPOUT} \
--weight-decay ${WEIGHT_DECAY} \
--gradient-accumulation ${GRADIENT_ACCUMULATION} \
$( [[ "$USE_FP16" == "True" ]] && echo "--fp16" ) \
$( [[ "$USE_PEFT" == "True" ]] && echo "--use-peft" ) \
$( [[ "$USE_INT4" == "True" ]] && echo "--use-int4" ) \
$( [[ "$PUSH_TO_HUB" == "True" ]] && echo "--push-to-hub --token ${HF_TOKEN} --repo-id ${REPO_ID}" )
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# > INFO    Running LLM
# > INFO    Params: Namespace(version=False, train=True, deploy=False, inference=False, data_path='data/', train_split='train', valid_split=None, text_column='text', rejected_text_column='rejected', prompt_text_column='prompt', model='TinyPixel/Llama-2-7B-bf16-sharded', model_ref=None, learning_rate=0.0002, num_train_epochs=5, train_batch_size=1, warmup_ratio=0.1, gradient_accumulation_steps=4, optimizer='adamw_torch', scheduler='linear', weight_decay=0.01, max_grad_norm=1.0, seed=42, add_eos_token=False, block_size=1024, use_peft=True, lora_r=16, lora_alpha=32, lora_dropout=0.05, logging_steps=-1, project_name='my_autotrain_llm', evaluation_strategy='epoch', save_total_limit=1, save_strategy='epoch', auto_find_batch_size=False, fp16=False, push_to_hub=True, use_int8=False, model_max_length=1024, repo_id='marynwangwu/llama-2-7b-tinypixel', use_int4=True, trainer='default', target_modules=None, merge_adapter=False, token='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', backend='default', username=None, use_flash_attention_2=False, log='none', disable_gradient_checkpointing=False, dpo_beta=0.1, func=<function run_llm_command_factory at 0x7b2ee2c51fc0>)
# Downloading data files: 100% 1/1 [00:00<00:00, 8719.97it/s]
# Extracting data files: 100% 1/1 [00:00<00:00, 515.33it/s]
# Generating train split: 500 examples [00:00, 7856.62 examples/s]
# tokenizer_config.json: 100% 676/676 [00:00<00:00, 3.41MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 3.41MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 10.2MB/s]
# special_tokens_map.json: 100% 411/411 [00:00<00:00, 2.24MB/s]
# config.json: 100% 626/626 [00:00<00:00, 3.16MB/s]
# pytorch_model.bin.index.json: 100% 26.8k/26.8k [00:00<00:00, 78.5MB/s]
# Downloading shards:   0% 0/14 [00:00<?, ?it/s]
# pytorch_model-00001-of-00014.bin:   0% 0.00/981M [00:00<?, ?B/s]
# pytorch_model-00001-of-00014.bin:   1% 10.5M/981M [00:00<00:12, 79.2MB/s]
# pytorch_model-00001-of-00014.bin:   3% 31.5M/981M [00:00<00:07, 119MB/s]
# pytorch_model-00001-of-00014.bin:   5% 52.4M/981M [00:00<00:06, 133MB/s]
# pytorch_model-00001-of-00014.bin:   7% 73.4M/981M [00:00<00:06, 139MB/s]
# pytorch_model-00001-of-00014.bin:  10% 94.4M/981M [00:00<00:06, 142MB/s]
# pytorch_model-00001-of-00014.bin:  12% 115M/981M [00:00<00:05, 144MB/s]
# pytorch_model-00001-of-00014.bin:  14% 136M/981M [00:00<00:05, 142MB/s]
# pytorch_model-00001-of-00014.bin:  16% 157M/981M [00:01<00:05, 140MB/s]
# pytorch_model-00001-of-00014.bin:  18% 178M/981M [00:01<00:05, 134MB/s]
# pytorch_model-00001-of-00014.bin:  20% 199M/981M [00:01<00:05, 135MB/s]
# pytorch_model-00001-of-00014.bin:  22% 220M/981M [00:01<00:05, 138MB/s]
# pytorch_model-00001-of-00014.bin:  25% 241M/981M [00:01<00:05, 142MB/s]
# pytorch_model-00001-of-00014.bin:  27% 262M/981M [00:01<00:04, 144MB/s]
# pytorch_model-00001-of-00014.bin:  29% 283M/981M [00:02<00:04, 146MB/s]
# pytorch_model-00001-of-00014.bin:  31% 304M/981M [00:02<00:04, 143MB/s]
# pytorch_model-00001-of-00014.bin:  33% 325M/981M [00:02<00:04, 144MB/s]
# pytorch_model-00001-of-00014.bin:  35% 346M/981M [00:02<00:04, 146MB/s]
# pytorch_model-00001-of-00014.bin:  37% 367M/981M [00:02<00:04, 144MB/s]
# pytorch_model-00001-of-00014.bin:  40% 388M/981M [00:02<00:04, 145MB/s]
# pytorch_model-00001-of-00014.bin:  42% 409M/981M [00:02<00:03, 146MB/s]
# pytorch_model-00001-of-00014.bin:  44% 430M/981M [00:03<00:03, 145MB/s]
# pytorch_model-00001-of-00014.bin:  46% 451M/981M [00:03<00:03, 144MB/s]
# pytorch_model-00001-of-00014.bin:  48% 472M/981M [00:03<00:03, 141MB/s]
# pytorch_model-00001-of-00014.bin:  50% 493M/981M [00:03<00:03, 139MB/s]
# pytorch_model-00001-of-00014.bin:  52% 514M/981M [00:03<00:03, 138MB/s]
# pytorch_model-00001-of-00014.bin:  54% 535M/981M [00:03<00:03, 139MB/s]
# pytorch_model-00001-of-00014.bin:  57% 556M/981M [00:03<00:03, 141MB/s]
# pytorch_model-00001-of-00014.bin:  59% 577M/981M [00:04<00:02, 141MB/s]
# pytorch_model-00001-of-00014.bin:  61% 598M/981M [00:04<00:02, 139MB/s]
# pytorch_model-00001-of-00014.bin:  63% 619M/981M [00:04<00:02, 135MB/s]
# pytorch_model-00001-of-00014.bin:  65% 640M/981M [00:04<00:02, 124MB/s]
# pytorch_model-00001-of-00014.bin:  67% 661M/981M [00:04<00:02, 124MB/s]
# pytorch_model-00001-of-00014.bin:  69% 682M/981M [00:04<00:02, 126MB/s]
# pytorch_model-00001-of-00014.bin:  72% 703M/981M [00:05<00:02, 128MB/s]
# pytorch_model-00001-of-00014.bin:  74% 724M/981M [00:05<00:01, 129MB/s]
# pytorch_model-00001-of-00014.bin:  76% 744M/981M [00:07<00:08, 29.4MB/s]
# pytorch_model-00001-of-00014.bin:  78% 765M/981M [00:07<00:05, 37.8MB/s]
# pytorch_model-00001-of-00014.bin:  80% 786M/981M [00:07<00:04, 48.4MB/s]
# pytorch_model-00001-of-00014.bin:  82% 807M/981M [00:07<00:02, 60.7MB/s]
# pytorch_model-00001-of-00014.bin:  84% 828M/981M [00:07<00:02, 73.2MB/s]
# pytorch_model-00001-of-00014.bin:  87% 849M/981M [00:08<00:01, 83.3MB/s]
# pytorch_model-00001-of-00014.bin:  89% 870M/981M [00:08<00:01, 96.0MB/s]
# pytorch_model-00001-of-00014.bin:  91% 891M/981M [00:08<00:00, 107MB/s]
# pytorch_model-00001-of-00014.bin:  93% 912M/981M [00:08<00:00, 114MB/s]
# pytorch_model-00001-of-00014.bin:  95% 933M/981M [00:08<00:00, 121MB/s]
# pytorch_model-00001-of-00014.bin:  97% 954M/981M [00:08<00:00, 125MB/s]
# pytorch_model-00001-of-00014.bin: 100% 981M/981M [00:09<00:00, 109MB/s]
# Downloading shards:   7% 1/14 [00:09<02:01,  9.32s/it]
# pytorch_model-00002-of-00014.bin:   0% 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00002-of-00014.bin:   2% 21.0M/967M [00:00<00:06, 149MB/s]
# pytorch_model-00002-of-00014.bin:   4% 41.9M/967M [00:00<00:06, 149MB/s]
# pytorch_model-00002-of-00014.bin:   7% 62.9M/967M [00:00<00:06, 150MB/s]
# pytorch_model-00002-of-00014.bin:   9% 83.9M/967M [00:00<00:05, 148MB/s]
# pytorch_model-00002-of-00014.bin:  11% 105M/967M [00:00<00:05, 146MB/s]
# pytorch_model-00002-of-00014.bin:  13% 126M/967M [00:00<00:05, 142MB/s]
# pytorch_model-00002-of-00014.bin:  15% 147M/967M [00:01<00:05, 142MB/s]
# pytorch_model-00002-of-00014.bin:  17% 168M/967M [00:01<00:05, 141MB/s]
# pytorch_model-00002-of-00014.bin:  20% 189M/967M [00:01<00:05, 141MB/s]
# pytorch_model-00002-of-00014.bin:  22% 210M/967M [00:01<00:05, 141MB/s]
# pytorch_model-00002-of-00014.bin:  24% 231M/967M [00:02<00:19, 37.1MB/s]
# pytorch_model-00002-of-00014.bin:  26% 252M/967M [00:03<00:14, 47.8MB/s]
# pytorch_model-00002-of-00014.bin:  28% 273M/967M [00:03<00:11, 60.2MB/s]
# pytorch_model-00002-of-00014.bin:  30% 294M/967M [00:03<00:09, 73.5MB/s]
# pytorch_model-00002-of-00014.bin:  33% 315M/967M [00:03<00:07, 83.9MB/s]
# pytorch_model-00002-of-00014.bin:  35% 336M/967M [00:03<00:06, 96.6MB/s]
# pytorch_model-00002-of-00014.bin:  37% 357M/967M [00:03<00:05, 107MB/s]
# pytorch_model-00002-of-00014.bin:  39% 377M/967M [00:04<00:05, 116MB/s]
# pytorch_model-00002-of-00014.bin:  41% 398M/967M [00:04<00:04, 121MB/s]
# pytorch_model-00002-of-00014.bin:  43% 419M/967M [00:04<00:04, 127MB/s]
# pytorch_model-00002-of-00014.bin:  46% 440M/967M [00:04<00:04, 131MB/s]
# pytorch_model-00002-of-00014.bin:  48% 461M/967M [00:04<00:03, 135MB/s]
# pytorch_model-00002-of-00014.bin:  50% 482M/967M [00:04<00:03, 138MB/s]
# pytorch_model-00002-of-00014.bin:  52% 503M/967M [00:04<00:03, 142MB/s]
# pytorch_model-00002-of-00014.bin:  54% 524M/967M [00:05<00:03, 144MB/s]
# pytorch_model-00002-of-00014.bin:  56% 545M/967M [00:05<00:02, 146MB/s]
# pytorch_model-00002-of-00014.bin:  59% 566M/967M [00:05<00:02, 141MB/s]
# pytorch_model-00002-of-00014.bin:  61% 587M/967M [00:05<00:02, 138MB/s]
# pytorch_model-00002-of-00014.bin:  63% 608M/967M [00:05<00:02, 138MB/s]
# pytorch_model-00002-of-00014.bin:  65% 629M/967M [00:05<00:02, 139MB/s]
# pytorch_model-00002-of-00014.bin:  67% 650M/967M [00:05<00:02, 139MB/s]
# pytorch_model-00002-of-00014.bin:  69% 671M/967M [00:06<00:02, 138MB/s]
# pytorch_model-00002-of-00014.bin:  72% 692M/967M [00:08<00:09, 30.3MB/s]
# pytorch_model-00002-of-00014.bin:  74% 713M/967M [00:08<00:06, 39.3MB/s]
# pytorch_model-00002-of-00014.bin:  76% 734M/967M [00:08<00:04, 50.0MB/s]
# pytorch_model-00002-of-00014.bin:  78% 755M/967M [00:08<00:03, 62.0MB/s]
# pytorch_model-00002-of-00014.bin:  80% 776M/967M [00:08<00:02, 74.3MB/s]
# pytorch_model-00002-of-00014.bin:  82% 797M/967M [00:08<00:01, 86.3MB/s]
# pytorch_model-00002-of-00014.bin:  85% 818M/967M [00:08<00:01, 93.2MB/s]
# pytorch_model-00002-of-00014.bin:  87% 839M/967M [00:09<00:01, 97.5MB/s]
# pytorch_model-00002-of-00014.bin:  89% 860M/967M [00:09<00:01, 104MB/s]
# pytorch_model-00002-of-00014.bin:  91% 881M/967M [00:09<00:00, 112MB/s]
# pytorch_model-00002-of-00014.bin:  93% 902M/967M [00:09<00:00, 119MB/s]
# pytorch_model-00002-of-00014.bin:  95% 923M/967M [00:09<00:00, 124MB/s]
# pytorch_model-00002-of-00014.bin:  98% 944M/967M [00:09<00:00, 130MB/s]
# pytorch_model-00002-of-00014.bin: 100% 967M/967M [00:10<00:00, 95.5MB/s]
# Downloading shards:  14% 2/14 [00:19<01:59,  9.93s/it]
# pytorch_model-00003-of-00014.bin:   0% 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00003-of-00014.bin:   2% 21.0M/967M [00:00<00:07, 133MB/s]
# pytorch_model-00003-of-00014.bin:   4% 41.9M/967M [00:00<00:07, 130MB/s]
# pytorch_model-00003-of-00014.bin:   7% 62.9M/967M [00:00<00:06, 136MB/s]
# pytorch_model-00003-of-00014.bin:   9% 83.9M/967M [00:00<00:06, 140MB/s]
# pytorch_model-00003-of-00014.bin:  11% 105M/967M [00:00<00:06, 143MB/s]
# pytorch_model-00003-of-00014.bin:  13% 126M/967M [00:00<00:05, 145MB/s]
# pytorch_model-00003-of-00014.bin:  15% 147M/967M [00:01<00:05, 145MB/s]
# pytorch_model-00003-of-00014.bin:  17% 168M/967M [00:01<00:05, 138MB/s]
# pytorch_model-00003-of-00014.bin:  20% 189M/967M [00:01<00:05, 133MB/s]
# pytorch_model-00003-of-00014.bin:  22% 210M/967M [00:01<00:05, 135MB/s]
# pytorch_model-00003-of-00014.bin:  24% 231M/967M [00:01<00:05, 137MB/s]
# pytorch_model-00003-of-00014.bin:  26% 252M/967M [00:01<00:05, 137MB/s]
# pytorch_model-00003-of-00014.bin:  28% 273M/967M [00:02<00:11, 59.0MB/s]
# pytorch_model-00003-of-00014.bin:  30% 294M/967M [00:02<00:09, 72.0MB/s]
# pytorch_model-00003-of-00014.bin:  33% 315M/967M [00:02<00:07, 85.2MB/s]
# pytorch_model-00003-of-00014.bin:  35% 336M/967M [00:03<00:06, 92.7MB/s]
# pytorch_model-00003-of-00014.bin:  37% 357M/967M [00:03<00:05, 104MB/s]
# pytorch_model-00003-of-00014.bin:  39% 377M/967M [00:03<00:05, 114MB/s]
# pytorch_model-00003-of-00014.bin:  41% 398M/967M [00:03<00:04, 121MB/s]
# pytorch_model-00003-of-00014.bin:  43% 419M/967M [00:03<00:04, 126MB/s]
# pytorch_model-00003-of-00014.bin:  46% 440M/967M [00:03<00:04, 129MB/s]
# pytorch_model-00003-of-00014.bin:  48% 461M/967M [00:03<00:03, 134MB/s]
# pytorch_model-00003-of-00014.bin:  50% 482M/967M [00:04<00:03, 138MB/s]
# pytorch_model-00003-of-00014.bin:  52% 503M/967M [00:04<00:03, 142MB/s]
# pytorch_model-00003-of-00014.bin:  54% 524M/967M [00:04<00:03, 143MB/s]
# pytorch_model-00003-of-00014.bin:  56% 545M/967M [00:04<00:02, 145MB/s]
# pytorch_model-00003-of-00014.bin:  59% 566M/967M [00:04<00:02, 143MB/s]
# pytorch_model-00003-of-00014.bin:  61% 587M/967M [00:04<00:02, 140MB/s]
# pytorch_model-00003-of-00014.bin:  63% 608M/967M [00:05<00:02, 141MB/s]
# pytorch_model-00003-of-00014.bin:  65% 629M/967M [00:05<00:02, 143MB/s]
# pytorch_model-00003-of-00014.bin:  67% 650M/967M [00:05<00:02, 145MB/s]
# pytorch_model-00003-of-00014.bin:  69% 671M/967M [00:05<00:03, 97.9MB/s]
# pytorch_model-00003-of-00014.bin:  72% 692M/967M [00:05<00:02, 108MB/s]
# pytorch_model-00003-of-00014.bin:  74% 713M/967M [00:05<00:02, 111MB/s]
# pytorch_model-00003-of-00014.bin:  76% 734M/967M [00:06<00:01, 117MB/s]
# pytorch_model-00003-of-00014.bin:  78% 755M/967M [00:06<00:01, 124MB/s]
# pytorch_model-00003-of-00014.bin:  80% 776M/967M [00:06<00:01, 123MB/s]
# pytorch_model-00003-of-00014.bin:  82% 797M/967M [00:06<00:01, 129MB/s]
# pytorch_model-00003-of-00014.bin:  85% 818M/967M [00:07<00:03, 48.6MB/s]
# pytorch_model-00003-of-00014.bin:  87% 839M/967M [00:07<00:02, 61.0MB/s]
# pytorch_model-00003-of-00014.bin:  89% 860M/967M [00:07<00:01, 74.0MB/s]
# pytorch_model-00003-of-00014.bin:  91% 881M/967M [00:08<00:00, 86.9MB/s]
# pytorch_model-00003-of-00014.bin:  93% 902M/967M [00:08<00:00, 98.8MB/s]
# pytorch_model-00003-of-00014.bin:  95% 923M/967M [00:08<00:00, 110MB/s]
# pytorch_model-00003-of-00014.bin:  98% 944M/967M [00:08<00:00, 118MB/s]
# pytorch_model-00003-of-00014.bin: 100% 967M/967M [00:08<00:00, 111MB/s]
# Downloading shards:  21% 3/14 [00:28<01:44,  9.48s/it]
# pytorch_model-00004-of-00014.bin:   0% 0.00/990M [00:00<?, ?B/s]
# pytorch_model-00004-of-00014.bin:   2% 21.0M/990M [00:00<00:07, 137MB/s]
# pytorch_model-00004-of-00014.bin:   4% 41.9M/990M [00:00<00:07, 132MB/s]
# pytorch_model-00004-of-00014.bin:   6% 62.9M/990M [00:00<00:06, 139MB/s]
# pytorch_model-00004-of-00014.bin:   8% 83.9M/990M [00:00<00:06, 143MB/s]
# pytorch_model-00004-of-00014.bin:  11% 105M/990M [00:00<00:06, 144MB/s]
# pytorch_model-00004-of-00014.bin:  13% 126M/990M [00:00<00:05, 145MB/s]
# pytorch_model-00004-of-00014.bin:  15% 147M/990M [00:01<00:05, 144MB/s]
# pytorch_model-00004-of-00014.bin:  17% 168M/990M [00:01<00:05, 138MB/s]
# pytorch_model-00004-of-00014.bin:  19% 189M/990M [00:01<00:06, 128MB/s]
# pytorch_model-00004-of-00014.bin:  21% 210M/990M [00:01<00:06, 126MB/s]
# pytorch_model-00004-of-00014.bin:  23% 231M/990M [00:01<00:06, 124MB/s]
# pytorch_model-00004-of-00014.bin:  25% 252M/990M [00:01<00:05, 123MB/s]
# pytorch_model-00004-of-00014.bin:  28% 273M/990M [00:03<00:22, 31.7MB/s]
# pytorch_model-00004-of-00014.bin:  30% 294M/990M [00:03<00:16, 41.2MB/s]
# pytorch_model-00004-of-00014.bin:  32% 315M/990M [00:04<00:12, 52.4MB/s]
# pytorch_model-00004-of-00014.bin:  34% 336M/990M [00:04<00:10, 65.1MB/s]
# pytorch_model-00004-of-00014.bin:  36% 357M/990M [00:04<00:08, 78.4MB/s]
# pytorch_model-00004-of-00014.bin:  38% 377M/990M [00:04<00:06, 91.5MB/s]
# pytorch_model-00004-of-00014.bin:  40% 398M/990M [00:04<00:05, 102MB/s]
# pytorch_model-00004-of-00014.bin:  42% 419M/990M [00:04<00:05, 107MB/s]
# pytorch_model-00004-of-00014.bin:  44% 440M/990M [00:04<00:04, 113MB/s]
# pytorch_model-00004-of-00014.bin:  47% 461M/990M [00:05<00:04, 119MB/s]
# pytorch_model-00004-of-00014.bin:  49% 482M/990M [00:05<00:04, 125MB/s]
# pytorch_model-00004-of-00014.bin:  51% 503M/990M [00:05<00:03, 131MB/s]
# pytorch_model-00004-of-00014.bin:  53% 524M/990M [00:05<00:03, 135MB/s]
# pytorch_model-00004-of-00014.bin:  55% 545M/990M [00:05<00:03, 140MB/s]
# pytorch_model-00004-of-00014.bin:  57% 566M/990M [00:05<00:02, 142MB/s]
# pytorch_model-00004-of-00014.bin:  59% 587M/990M [00:05<00:02, 143MB/s]
# pytorch_model-00004-of-00014.bin:  61% 608M/990M [00:06<00:02, 141MB/s]
# pytorch_model-00004-of-00014.bin:  64% 629M/990M [00:06<00:02, 140MB/s]
# pytorch_model-00004-of-00014.bin:  66% 650M/990M [00:06<00:02, 140MB/s]
# pytorch_model-00004-of-00014.bin:  68% 671M/990M [00:06<00:02, 140MB/s]
# pytorch_model-00004-of-00014.bin:  70% 692M/990M [00:06<00:02, 141MB/s]
# pytorch_model-00004-of-00014.bin:  72% 713M/990M [00:08<00:10, 26.9MB/s]
# pytorch_model-00004-of-00014.bin:  74% 734M/990M [00:09<00:07, 35.7MB/s]
# pytorch_model-00004-of-00014.bin:  76% 755M/990M [00:09<00:05, 46.2MB/s]
# pytorch_model-00004-of-00014.bin:  78% 776M/990M [00:09<00:03, 58.2MB/s]
# pytorch_model-00004-of-00014.bin:  81% 797M/990M [00:09<00:02, 70.3MB/s]
# pytorch_model-00004-of-00014.bin:  83% 818M/990M [00:09<00:02, 81.7MB/s]
# pytorch_model-00004-of-00014.bin:  85% 839M/990M [00:09<00:01, 92.2MB/s]
# pytorch_model-00004-of-00014.bin:  87% 860M/990M [00:09<00:01, 102MB/s]
# pytorch_model-00004-of-00014.bin:  89% 881M/990M [00:10<00:00, 112MB/s]
# pytorch_model-00004-of-00014.bin:  91% 902M/990M [00:10<00:00, 119MB/s]
# pytorch_model-00004-of-00014.bin:  93% 923M/990M [00:10<00:00, 126MB/s]
# pytorch_model-00004-of-00014.bin:  95% 944M/990M [00:10<00:00, 131MB/s]
# pytorch_model-00004-of-00014.bin:  97% 965M/990M [00:10<00:00, 136MB/s]
# pytorch_model-00004-of-00014.bin: 100% 990M/990M [00:10<00:00, 91.0MB/s]
# Downloading shards:  29% 4/14 [00:39<01:41, 10.14s/it]
# pytorch_model-00005-of-00014.bin:   0% 0.00/944M [00:00<?, ?B/s]
# pytorch_model-00005-of-00014.bin:   2% 21.0M/944M [00:00<00:06, 148MB/s]
# pytorch_model-00005-of-00014.bin:   4% 41.9M/944M [00:00<00:06, 137MB/s]
# pytorch_model-00005-of-00014.bin:   7% 62.9M/944M [00:00<00:06, 128MB/s]
# pytorch_model-00005-of-00014.bin:   9% 83.9M/944M [00:00<00:06, 131MB/s]
# pytorch_model-00005-of-00014.bin:  11% 105M/944M [00:00<00:06, 134MB/s]
# pytorch_model-00005-of-00014.bin:  13% 126M/944M [00:00<00:06, 136MB/s]
# pytorch_model-00005-of-00014.bin:  16% 147M/944M [00:02<00:23, 34.5MB/s]
# pytorch_model-00005-of-00014.bin:  18% 168M/944M [00:02<00:16, 45.7MB/s]
# pytorch_model-00005-of-00014.bin:  20% 189M/944M [00:02<00:13, 58.0MB/s]
# pytorch_model-00005-of-00014.bin:  22% 210M/944M [00:02<00:10, 70.1MB/s]
# pytorch_model-00005-of-00014.bin:  24% 231M/944M [00:03<00:08, 83.2MB/s]
# pytorch_model-00005-of-00014.bin:  27% 252M/944M [00:03<00:07, 95.4MB/s]
# pytorch_model-00005-of-00014.bin:  29% 273M/944M [00:03<00:06, 103MB/s]
# pytorch_model-00005-of-00014.bin:  31% 294M/944M [00:03<00:05, 108MB/s]
# pytorch_model-00005-of-00014.bin:  33% 315M/944M [00:03<00:05, 109MB/s]
# pytorch_model-00005-of-00014.bin:  36% 336M/944M [00:03<00:05, 115MB/s]
# pytorch_model-00005-of-00014.bin:  38% 357M/944M [00:04<00:04, 121MB/s]
# pytorch_model-00005-of-00014.bin:  40% 377M/944M [00:04<00:04, 125MB/s]
# pytorch_model-00005-of-00014.bin:  42% 398M/944M [00:04<00:04, 129MB/s]
# pytorch_model-00005-of-00014.bin:  44% 419M/944M [00:04<00:03, 133MB/s]
# pytorch_model-00005-of-00014.bin:  47% 440M/944M [00:04<00:03, 133MB/s]
# pytorch_model-00005-of-00014.bin:  49% 461M/944M [00:04<00:03, 132MB/s]
# pytorch_model-00005-of-00014.bin:  51% 482M/944M [00:04<00:03, 128MB/s]
# pytorch_model-00005-of-00014.bin:  53% 503M/944M [00:05<00:03, 125MB/s]
# pytorch_model-00005-of-00014.bin:  56% 524M/944M [00:05<00:03, 122MB/s]
# pytorch_model-00005-of-00014.bin:  58% 545M/944M [00:05<00:03, 119MB/s]
# pytorch_model-00005-of-00014.bin:  60% 566M/944M [00:07<00:13, 27.7MB/s]
# pytorch_model-00005-of-00014.bin:  61% 577M/944M [00:07<00:12, 29.3MB/s]
# pytorch_model-00005-of-00014.bin:  62% 587M/944M [00:08<00:10, 33.2MB/s]
# pytorch_model-00005-of-00014.bin:  63% 598M/944M [00:08<00:08, 38.6MB/s]
# pytorch_model-00005-of-00014.bin:  66% 619M/944M [00:08<00:06, 52.9MB/s]
# pytorch_model-00005-of-00014.bin:  68% 640M/944M [00:08<00:04, 68.6MB/s]
# pytorch_model-00005-of-00014.bin:  70% 661M/944M [00:08<00:03, 83.9MB/s]
# pytorch_model-00005-of-00014.bin:  72% 682M/944M [00:08<00:02, 97.9MB/s]
# pytorch_model-00005-of-00014.bin:  74% 703M/944M [00:08<00:02, 108MB/s]
# pytorch_model-00005-of-00014.bin:  77% 724M/944M [00:09<00:01, 114MB/s]
# pytorch_model-00005-of-00014.bin:  79% 744M/944M [00:09<00:01, 118MB/s]
# pytorch_model-00005-of-00014.bin:  81% 765M/944M [00:09<00:01, 122MB/s]
# pytorch_model-00005-of-00014.bin:  83% 786M/944M [00:09<00:01, 128MB/s]
# pytorch_model-00005-of-00014.bin:  86% 807M/944M [00:09<00:01, 133MB/s]
# pytorch_model-00005-of-00014.bin:  88% 828M/944M [00:09<00:00, 137MB/s]
# pytorch_model-00005-of-00014.bin:  90% 849M/944M [00:09<00:00, 140MB/s]
# pytorch_model-00005-of-00014.bin:  92% 870M/944M [00:10<00:00, 142MB/s]
# pytorch_model-00005-of-00014.bin:  94% 891M/944M [00:10<00:00, 143MB/s]
# pytorch_model-00005-of-00014.bin:  97% 912M/944M [00:12<00:00, 32.1MB/s]
# pytorch_model-00005-of-00014.bin:  98% 923M/944M [00:12<00:00, 33.4MB/s]
# pytorch_model-00005-of-00014.bin:  99% 933M/944M [00:12<00:00, 37.2MB/s]
# pytorch_model-00005-of-00014.bin: 100% 944M/944M [00:12<00:00, 73.2MB/s]
# Downloading shards:  36% 5/14 [00:52<01:41, 11.23s/it]
# pytorch_model-00006-of-00014.bin:   0% 0.00/990M [00:00<?, ?B/s]
# pytorch_model-00006-of-00014.bin:   2% 21.0M/990M [00:00<00:07, 127MB/s]
# pytorch_model-00006-of-00014.bin:   4% 41.9M/990M [00:00<00:06, 139MB/s]
# pytorch_model-00006-of-00014.bin:   6% 62.9M/990M [00:00<00:06, 143MB/s]
# pytorch_model-00006-of-00014.bin:   8% 83.9M/990M [00:00<00:06, 145MB/s]
# pytorch_model-00006-of-00014.bin:  11% 105M/990M [00:00<00:06, 146MB/s]
# pytorch_model-00006-of-00014.bin:  13% 126M/990M [00:00<00:05, 146MB/s]
# pytorch_model-00006-of-00014.bin:  15% 147M/990M [00:01<00:06, 138MB/s]
# pytorch_model-00006-of-00014.bin:  17% 168M/990M [00:01<00:05, 138MB/s]
# pytorch_model-00006-of-00014.bin:  19% 189M/990M [00:01<00:05, 134MB/s]
# pytorch_model-00006-of-00014.bin:  21% 210M/990M [00:01<00:05, 138MB/s]
# pytorch_model-00006-of-00014.bin:  23% 231M/990M [00:01<00:05, 141MB/s]
# pytorch_model-00006-of-00014.bin:  25% 252M/990M [00:01<00:05, 141MB/s]
# pytorch_model-00006-of-00014.bin:  28% 273M/990M [00:01<00:04, 144MB/s]
# pytorch_model-00006-of-00014.bin:  30% 294M/990M [00:02<00:04, 146MB/s]
# pytorch_model-00006-of-00014.bin:  32% 315M/990M [00:02<00:04, 143MB/s]
# pytorch_model-00006-of-00014.bin:  34% 336M/990M [00:02<00:04, 137MB/s]
# pytorch_model-00006-of-00014.bin:  36% 357M/990M [00:02<00:04, 137MB/s]
# pytorch_model-00006-of-00014.bin:  38% 377M/990M [00:02<00:04, 137MB/s]
# pytorch_model-00006-of-00014.bin:  40% 398M/990M [00:02<00:04, 138MB/s]
# pytorch_model-00006-of-00014.bin:  42% 419M/990M [00:04<00:19, 29.9MB/s]
# pytorch_model-00006-of-00014.bin:  44% 440M/990M [00:04<00:14, 39.2MB/s]
# pytorch_model-00006-of-00014.bin:  47% 461M/990M [00:05<00:10, 49.9MB/s]
# pytorch_model-00006-of-00014.bin:  49% 482M/990M [00:05<00:08, 61.0MB/s]
# pytorch_model-00006-of-00014.bin:  51% 503M/990M [00:05<00:06, 73.6MB/s]
# pytorch_model-00006-of-00014.bin:  53% 524M/990M [00:05<00:05, 85.7MB/s]
# pytorch_model-00006-of-00014.bin:  55% 545M/990M [00:05<00:04, 95.5MB/s]
# pytorch_model-00006-of-00014.bin:  57% 566M/990M [00:05<00:04, 101MB/s]
# pytorch_model-00006-of-00014.bin:  59% 587M/990M [00:06<00:03, 107MB/s]
# pytorch_model-00006-of-00014.bin:  61% 608M/990M [00:06<00:03, 116MB/s]
# pytorch_model-00006-of-00014.bin:  64% 629M/990M [00:06<00:02, 124MB/s]
# pytorch_model-00006-of-00014.bin:  66% 650M/990M [00:06<00:02, 129MB/s]
# pytorch_model-00006-of-00014.bin:  68% 671M/990M [00:06<00:02, 133MB/s]
# pytorch_model-00006-of-00014.bin:  70% 692M/990M [00:06<00:02, 138MB/s]
# pytorch_model-00006-of-00014.bin:  72% 713M/990M [00:06<00:01, 140MB/s]
# pytorch_model-00006-of-00014.bin:  74% 734M/990M [00:07<00:01, 142MB/s]
# pytorch_model-00006-of-00014.bin:  76% 755M/990M [00:07<00:01, 142MB/s]
# pytorch_model-00006-of-00014.bin:  78% 776M/990M [00:07<00:01, 144MB/s]
# pytorch_model-00006-of-00014.bin:  81% 797M/990M [00:07<00:01, 140MB/s]
# pytorch_model-00006-of-00014.bin:  83% 818M/990M [00:07<00:01, 138MB/s]
# pytorch_model-00006-of-00014.bin:  85% 839M/990M [00:07<00:01, 139MB/s]
# pytorch_model-00006-of-00014.bin:  87% 860M/990M [00:08<00:00, 137MB/s]
# pytorch_model-00006-of-00014.bin:  89% 881M/990M [00:08<00:00, 137MB/s]
# pytorch_model-00006-of-00014.bin:  91% 902M/990M [00:09<00:02, 34.9MB/s]
# pytorch_model-00006-of-00014.bin:  93% 923M/990M [00:09<00:01, 44.7MB/s]
# pytorch_model-00006-of-00014.bin:  95% 944M/990M [00:10<00:00, 56.4MB/s]
# pytorch_model-00006-of-00014.bin:  97% 965M/990M [00:10<00:00, 69.2MB/s]
# pytorch_model-00006-of-00014.bin: 100% 990M/990M [00:10<00:00, 94.7MB/s]
# Downloading shards:  43% 6/14 [01:03<01:28, 11.05s/it]
# pytorch_model-00007-of-00014.bin:   0% 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00007-of-00014.bin:   2% 21.0M/967M [00:00<00:06, 145MB/s]
# pytorch_model-00007-of-00014.bin:   4% 41.9M/967M [00:00<00:06, 145MB/s]
# pytorch_model-00007-of-00014.bin:   7% 62.9M/967M [00:00<00:06, 143MB/s]
# pytorch_model-00007-of-00014.bin:   9% 83.9M/967M [00:00<00:06, 139MB/s]
# pytorch_model-00007-of-00014.bin:  11% 105M/967M [00:00<00:06, 139MB/s]
# pytorch_model-00007-of-00014.bin:  13% 126M/967M [00:00<00:06, 140MB/s]
# pytorch_model-00007-of-00014.bin:  15% 147M/967M [00:01<00:05, 138MB/s]
# pytorch_model-00007-of-00014.bin:  17% 168M/967M [00:01<00:05, 141MB/s]
# pytorch_model-00007-of-00014.bin:  20% 189M/967M [00:01<00:08, 94.8MB/s]
# pytorch_model-00007-of-00014.bin:  22% 210M/967M [00:01<00:07, 106MB/s]
# pytorch_model-00007-of-00014.bin:  24% 231M/967M [00:01<00:06, 116MB/s]
# pytorch_model-00007-of-00014.bin:  26% 252M/967M [00:02<00:05, 123MB/s]
# pytorch_model-00007-of-00014.bin:  28% 273M/967M [00:02<00:05, 128MB/s]
# pytorch_model-00007-of-00014.bin:  30% 294M/967M [00:02<00:05, 132MB/s]
# pytorch_model-00007-of-00014.bin:  33% 315M/967M [00:02<00:04, 131MB/s]
# pytorch_model-00007-of-00014.bin:  35% 336M/967M [00:02<00:04, 133MB/s]
# pytorch_model-00007-of-00014.bin:  37% 357M/967M [00:02<00:04, 135MB/s]
# pytorch_model-00007-of-00014.bin:  39% 377M/967M [00:04<00:15, 38.5MB/s]
# pytorch_model-00007-of-00014.bin:  41% 398M/967M [00:04<00:11, 49.3MB/s]
# pytorch_model-00007-of-00014.bin:  43% 419M/967M [00:04<00:09, 60.0MB/s]
# pytorch_model-00007-of-00014.bin:  46% 440M/967M [00:04<00:07, 73.2MB/s]
# pytorch_model-00007-of-00014.bin:  48% 461M/967M [00:04<00:05, 86.4MB/s]
# pytorch_model-00007-of-00014.bin:  50% 482M/967M [00:04<00:04, 98.1MB/s]
# pytorch_model-00007-of-00014.bin:  52% 503M/967M [00:05<00:04, 104MB/s]
# pytorch_model-00007-of-00014.bin:  54% 524M/967M [00:05<00:04, 106MB/s]
# pytorch_model-00007-of-00014.bin:  56% 545M/967M [00:05<00:04, 105MB/s]
# pytorch_model-00007-of-00014.bin:  59% 566M/967M [00:05<00:03, 110MB/s]
# pytorch_model-00007-of-00014.bin:  61% 587M/967M [00:05<00:03, 118MB/s]
# pytorch_model-00007-of-00014.bin:  63% 608M/967M [00:05<00:02, 125MB/s]
# pytorch_model-00007-of-00014.bin:  65% 629M/967M [00:06<00:02, 128MB/s]
# pytorch_model-00007-of-00014.bin:  67% 650M/967M [00:06<00:02, 131MB/s]
# pytorch_model-00007-of-00014.bin:  69% 671M/967M [00:06<00:02, 134MB/s]
# pytorch_model-00007-of-00014.bin:  72% 692M/967M [00:06<00:02, 128MB/s]
# pytorch_model-00007-of-00014.bin:  74% 713M/967M [00:06<00:02, 127MB/s]
# pytorch_model-00007-of-00014.bin:  76% 734M/967M [00:06<00:01, 128MB/s]
# pytorch_model-00007-of-00014.bin:  78% 755M/967M [00:07<00:01, 131MB/s]
# pytorch_model-00007-of-00014.bin:  80% 776M/967M [00:07<00:01, 134MB/s]
# pytorch_model-00007-of-00014.bin:  82% 797M/967M [00:07<00:01, 136MB/s]
# pytorch_model-00007-of-00014.bin:  85% 818M/967M [00:07<00:01, 139MB/s]
# pytorch_model-00007-of-00014.bin:  87% 839M/967M [00:07<00:00, 128MB/s]
# pytorch_model-00007-of-00014.bin:  89% 860M/967M [00:07<00:00, 122MB/s]
# pytorch_model-00007-of-00014.bin:  91% 881M/967M [00:08<00:00, 124MB/s]
# pytorch_model-00007-of-00014.bin:  93% 902M/967M [00:08<00:00, 124MB/s]
# pytorch_model-00007-of-00014.bin:  95% 923M/967M [00:08<00:00, 121MB/s]
# pytorch_model-00007-of-00014.bin:  98% 944M/967M [00:08<00:00, 119MB/s]
# pytorch_model-00007-of-00014.bin: 100% 967M/967M [00:08<00:00, 110MB/s]
# Downloading shards:  50% 7/14 [01:12<01:12, 10.40s/it]
# pytorch_model-00008-of-00014.bin:   0% 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00008-of-00014.bin:   2% 21.0M/967M [00:00<00:14, 66.8MB/s]
# pytorch_model-00008-of-00014.bin:   4% 41.9M/967M [00:00<00:09, 98.8MB/s]
# pytorch_model-00008-of-00014.bin:   7% 62.9M/967M [00:00<00:07, 117MB/s]
# pytorch_model-00008-of-00014.bin:   9% 83.9M/967M [00:00<00:06, 127MB/s]
# pytorch_model-00008-of-00014.bin:  11% 105M/967M [00:00<00:06, 135MB/s]
# pytorch_model-00008-of-00014.bin:  13% 126M/967M [00:01<00:06, 127MB/s]
# pytorch_model-00008-of-00014.bin:  15% 147M/967M [00:01<00:06, 129MB/s]
# pytorch_model-00008-of-00014.bin:  17% 168M/967M [00:01<00:06, 133MB/s]
# pytorch_model-00008-of-00014.bin:  20% 189M/967M [00:01<00:05, 130MB/s]
# pytorch_model-00008-of-00014.bin:  22% 210M/967M [00:01<00:05, 135MB/s]
# pytorch_model-00008-of-00014.bin:  24% 231M/967M [00:01<00:05, 139MB/s]
# pytorch_model-00008-of-00014.bin:  26% 252M/967M [00:01<00:05, 142MB/s]
# pytorch_model-00008-of-00014.bin:  28% 273M/967M [00:02<00:04, 144MB/s]
# pytorch_model-00008-of-00014.bin:  30% 294M/967M [00:02<00:04, 145MB/s]
# pytorch_model-00008-of-00014.bin:  33% 315M/967M [00:02<00:04, 144MB/s]
# pytorch_model-00008-of-00014.bin:  35% 336M/967M [00:02<00:04, 144MB/s]
# pytorch_model-00008-of-00014.bin:  37% 357M/967M [00:02<00:04, 144MB/s]
# pytorch_model-00008-of-00014.bin:  39% 377M/967M [00:02<00:04, 142MB/s]
# pytorch_model-00008-of-00014.bin:  41% 398M/967M [00:02<00:04, 141MB/s]
# pytorch_model-00008-of-00014.bin:  43% 419M/967M [00:03<00:03, 140MB/s]
# pytorch_model-00008-of-00014.bin:  46% 440M/967M [00:03<00:03, 139MB/s]
# pytorch_model-00008-of-00014.bin:  48% 461M/967M [00:03<00:03, 131MB/s]
# pytorch_model-00008-of-00014.bin:  50% 482M/967M [00:03<00:03, 132MB/s]
# pytorch_model-00008-of-00014.bin:  52% 503M/967M [00:03<00:03, 134MB/s]
# pytorch_model-00008-of-00014.bin:  54% 524M/967M [00:03<00:03, 135MB/s]
# pytorch_model-00008-of-00014.bin:  56% 545M/967M [00:04<00:03, 133MB/s]
# pytorch_model-00008-of-00014.bin:  59% 566M/967M [00:04<00:02, 136MB/s]
# pytorch_model-00008-of-00014.bin:  61% 587M/967M [00:04<00:02, 139MB/s]
# pytorch_model-00008-of-00014.bin:  63% 608M/967M [00:04<00:02, 142MB/s]
# pytorch_model-00008-of-00014.bin:  65% 629M/967M [00:04<00:02, 144MB/s]
# pytorch_model-00008-of-00014.bin:  67% 650M/967M [00:04<00:02, 144MB/s]
# pytorch_model-00008-of-00014.bin:  69% 671M/967M [00:04<00:02, 140MB/s]
# pytorch_model-00008-of-00014.bin:  72% 692M/967M [00:05<00:02, 137MB/s]
# pytorch_model-00008-of-00014.bin:  74% 713M/967M [00:05<00:01, 135MB/s]
# pytorch_model-00008-of-00014.bin:  76% 734M/967M [00:05<00:01, 123MB/s]
# pytorch_model-00008-of-00014.bin:  78% 755M/967M [00:05<00:01, 125MB/s]
# pytorch_model-00008-of-00014.bin:  80% 776M/967M [00:05<00:01, 131MB/s]
# pytorch_model-00008-of-00014.bin:  82% 797M/967M [00:05<00:01, 136MB/s]
# pytorch_model-00008-of-00014.bin:  85% 818M/967M [00:06<00:01, 133MB/s]
# pytorch_model-00008-of-00014.bin:  87% 839M/967M [00:06<00:01, 121MB/s]
# pytorch_model-00008-of-00014.bin:  89% 860M/967M [00:06<00:00, 118MB/s]
# pytorch_model-00008-of-00014.bin:  91% 881M/967M [00:06<00:00, 124MB/s]
# pytorch_model-00008-of-00014.bin:  93% 902M/967M [00:06<00:00, 129MB/s]
# pytorch_model-00008-of-00014.bin:  95% 923M/967M [00:06<00:00, 133MB/s]
# pytorch_model-00008-of-00014.bin:  98% 944M/967M [00:07<00:00, 137MB/s]
# pytorch_model-00008-of-00014.bin: 100% 967M/967M [00:07<00:00, 133MB/s]
# Downloading shards:  57% 8/14 [01:20<00:56,  9.48s/it]
# pytorch_model-00009-of-00014.bin:   0% 0.00/990M [00:00<?, ?B/s]
# pytorch_model-00009-of-00014.bin:   2% 21.0M/990M [00:00<00:06, 149MB/s]
# pytorch_model-00009-of-00014.bin:   4% 41.9M/990M [00:00<00:06, 149MB/s]
# pytorch_model-00009-of-00014.bin:   6% 62.9M/990M [00:00<00:06, 136MB/s]
# pytorch_model-00009-of-00014.bin:   8% 83.9M/990M [00:00<00:06, 137MB/s]
# pytorch_model-00009-of-00014.bin:  11% 105M/990M [00:00<00:06, 138MB/s]
# pytorch_model-00009-of-00014.bin:  13% 126M/990M [00:00<00:06, 137MB/s]
# pytorch_model-00009-of-00014.bin:  15% 147M/990M [00:01<00:06, 139MB/s]
# pytorch_model-00009-of-00014.bin:  17% 168M/990M [00:02<00:26, 31.3MB/s]
# pytorch_model-00009-of-00014.bin:  19% 189M/990M [00:02<00:19, 41.3MB/s]
# pytorch_model-00009-of-00014.bin:  21% 210M/990M [00:03<00:15, 51.5MB/s]
# pytorch_model-00009-of-00014.bin:  23% 231M/990M [00:03<00:11, 63.3MB/s]
# pytorch_model-00009-of-00014.bin:  25% 252M/990M [00:03<00:09, 74.6MB/s]
# pytorch_model-00009-of-00014.bin:  28% 273M/990M [00:03<00:08, 85.3MB/s]
# pytorch_model-00009-of-00014.bin:  30% 294M/990M [00:03<00:07, 96.2MB/s]
# pytorch_model-00009-of-00014.bin:  32% 315M/990M [00:03<00:06, 107MB/s]
# pytorch_model-00009-of-00014.bin:  34% 336M/990M [00:04<00:05, 115MB/s]
# pytorch_model-00009-of-00014.bin:  36% 357M/990M [00:04<00:05, 121MB/s]
# pytorch_model-00009-of-00014.bin:  38% 377M/990M [00:04<00:04, 126MB/s]
# pytorch_model-00009-of-00014.bin:  40% 398M/990M [00:04<00:04, 125MB/s]
# pytorch_model-00009-of-00014.bin:  42% 419M/990M [00:04<00:04, 120MB/s]
# pytorch_model-00009-of-00014.bin:  44% 440M/990M [00:04<00:04, 119MB/s]
# pytorch_model-00009-of-00014.bin:  47% 461M/990M [00:05<00:04, 123MB/s]
# pytorch_model-00009-of-00014.bin:  49% 482M/990M [00:05<00:03, 127MB/s]
# pytorch_model-00009-of-00014.bin:  51% 503M/990M [00:05<00:03, 129MB/s]
# pytorch_model-00009-of-00014.bin:  53% 524M/990M [00:05<00:03, 133MB/s]
# pytorch_model-00009-of-00014.bin:  55% 545M/990M [00:05<00:03, 135MB/s]
# pytorch_model-00009-of-00014.bin:  57% 566M/990M [00:05<00:03, 138MB/s]
# pytorch_model-00009-of-00014.bin:  59% 587M/990M [00:06<00:03, 130MB/s]
# pytorch_model-00009-of-00014.bin:  61% 608M/990M [00:06<00:02, 133MB/s]
# pytorch_model-00009-of-00014.bin:  64% 629M/990M [00:06<00:02, 132MB/s]
# pytorch_model-00009-of-00014.bin:  66% 650M/990M [00:06<00:02, 136MB/s]
# pytorch_model-00009-of-00014.bin:  68% 671M/990M [00:06<00:02, 134MB/s]
# pytorch_model-00009-of-00014.bin:  70% 692M/990M [00:07<00:06, 48.1MB/s]
# pytorch_model-00009-of-00014.bin:  72% 713M/990M [00:07<00:04, 59.9MB/s]
# pytorch_model-00009-of-00014.bin:  74% 734M/990M [00:08<00:03, 72.6MB/s]
# pytorch_model-00009-of-00014.bin:  76% 755M/990M [00:08<00:02, 85.7MB/s]
# pytorch_model-00009-of-00014.bin:  78% 776M/990M [00:08<00:02, 98.1MB/s]
# pytorch_model-00009-of-00014.bin:  81% 797M/990M [00:08<00:01, 109MB/s]
# pytorch_model-00009-of-00014.bin:  83% 818M/990M [00:08<00:01, 114MB/s]
# pytorch_model-00009-of-00014.bin:  85% 839M/990M [00:08<00:01, 118MB/s]
# pytorch_model-00009-of-00014.bin:  87% 860M/990M [00:08<00:01, 122MB/s]
# pytorch_model-00009-of-00014.bin:  89% 881M/990M [00:09<00:00, 125MB/s]
# pytorch_model-00009-of-00014.bin:  91% 902M/990M [00:09<00:00, 131MB/s]
# pytorch_model-00009-of-00014.bin:  93% 923M/990M [00:09<00:00, 135MB/s]
# pytorch_model-00009-of-00014.bin:  95% 944M/990M [00:09<00:00, 139MB/s]
# pytorch_model-00009-of-00014.bin:  97% 965M/990M [00:09<00:00, 141MB/s]
# pytorch_model-00009-of-00014.bin: 100% 990M/990M [00:10<00:00, 98.0MB/s]
# Downloading shards:  64% 9/14 [01:30<00:48,  9.75s/it]
# pytorch_model-00010-of-00014.bin:   0% 0.00/944M [00:00<?, ?B/s]
# pytorch_model-00010-of-00014.bin:   2% 21.0M/944M [00:00<00:06, 149MB/s]
# pytorch_model-00010-of-00014.bin:   4% 41.9M/944M [00:00<00:06, 131MB/s]
# pytorch_model-00010-of-00014.bin:   7% 62.9M/944M [00:00<00:06, 134MB/s]
# pytorch_model-00010-of-00014.bin:   9% 83.9M/944M [00:00<00:06, 133MB/s]
# pytorch_model-00010-of-00014.bin:  11% 105M/944M [00:00<00:06, 135MB/s]
# pytorch_model-00010-of-00014.bin:  13% 126M/944M [00:00<00:06, 136MB/s]
# pytorch_model-00010-of-00014.bin:  16% 147M/944M [00:02<00:23, 34.5MB/s]
# pytorch_model-00010-of-00014.bin:  18% 168M/944M [00:02<00:17, 45.6MB/s]
# pytorch_model-00010-of-00014.bin:  20% 189M/944M [00:02<00:13, 56.6MB/s]
# pytorch_model-00010-of-00014.bin:  22% 210M/944M [00:02<00:10, 70.0MB/s]
# pytorch_model-00010-of-00014.bin:  24% 231M/944M [00:03<00:08, 83.2MB/s]
# pytorch_model-00010-of-00014.bin:  27% 252M/944M [00:03<00:07, 93.8MB/s]
# pytorch_model-00010-of-00014.bin:  29% 273M/944M [00:03<00:06, 104MB/s]
# pytorch_model-00010-of-00014.bin:  31% 294M/944M [00:03<00:05, 112MB/s]
# pytorch_model-00010-of-00014.bin:  33% 315M/944M [00:03<00:05, 119MB/s]
# pytorch_model-00010-of-00014.bin:  36% 336M/944M [00:03<00:04, 126MB/s]
# pytorch_model-00010-of-00014.bin:  38% 357M/944M [00:03<00:04, 131MB/s]
# pytorch_model-00010-of-00014.bin:  40% 377M/944M [00:04<00:04, 136MB/s]
# pytorch_model-00010-of-00014.bin:  42% 398M/944M [00:04<00:03, 139MB/s]
# pytorch_model-00010-of-00014.bin:  44% 419M/944M [00:04<00:03, 142MB/s]
# pytorch_model-00010-of-00014.bin:  47% 440M/944M [00:04<00:03, 143MB/s]
# pytorch_model-00010-of-00014.bin:  49% 461M/944M [00:04<00:03, 132MB/s]
# pytorch_model-00010-of-00014.bin:  51% 482M/944M [00:04<00:03, 132MB/s]
# pytorch_model-00010-of-00014.bin:  53% 503M/944M [00:05<00:03, 132MB/s]
# pytorch_model-00010-of-00014.bin:  56% 524M/944M [00:05<00:03, 131MB/s]
# pytorch_model-00010-of-00014.bin:  58% 545M/944M [00:05<00:02, 133MB/s]
# pytorch_model-00010-of-00014.bin:  60% 566M/944M [00:07<00:13, 27.9MB/s]
# pytorch_model-00010-of-00014.bin:  62% 587M/944M [00:07<00:09, 36.2MB/s]
# pytorch_model-00010-of-00014.bin:  64% 608M/944M [00:07<00:07, 46.3MB/s]
# pytorch_model-00010-of-00014.bin:  67% 629M/944M [00:07<00:05, 57.9MB/s]
# pytorch_model-00010-of-00014.bin:  69% 650M/944M [00:08<00:04, 70.5MB/s]
# pytorch_model-00010-of-00014.bin:  71% 671M/944M [00:08<00:03, 82.8MB/s]
# pytorch_model-00010-of-00014.bin:  73% 692M/944M [00:08<00:02, 93.6MB/s]
# pytorch_model-00010-of-00014.bin:  76% 713M/944M [00:08<00:02, 101MB/s]
# pytorch_model-00010-of-00014.bin:  78% 734M/944M [00:08<00:01, 107MB/s]
# pytorch_model-00010-of-00014.bin:  80% 755M/944M [00:08<00:01, 115MB/s]
# pytorch_model-00010-of-00014.bin:  82% 776M/944M [00:09<00:01, 119MB/s]
# pytorch_model-00010-of-00014.bin:  84% 797M/944M [00:09<00:01, 123MB/s]
# pytorch_model-00010-of-00014.bin:  87% 818M/944M [00:09<00:00, 129MB/s]
# pytorch_model-00010-of-00014.bin:  89% 839M/944M [00:09<00:00, 133MB/s]
# pytorch_model-00010-of-00014.bin:  91% 860M/944M [00:09<00:00, 136MB/s]
# pytorch_model-00010-of-00014.bin:  93% 881M/944M [00:09<00:00, 139MB/s]
# pytorch_model-00010-of-00014.bin:  96% 902M/944M [00:09<00:00, 142MB/s]
# pytorch_model-00010-of-00014.bin:  98% 923M/944M [00:10<00:00, 143MB/s]
# pytorch_model-00010-of-00014.bin: 100% 944M/944M [00:10<00:00, 91.9MB/s]
# Downloading shards:  71% 10/14 [01:41<00:39,  9.98s/it]
# pytorch_model-00011-of-00014.bin:   0% 0.00/990M [00:00<?, ?B/s]
# pytorch_model-00011-of-00014.bin:   2% 21.0M/990M [00:00<00:07, 136MB/s]
# pytorch_model-00011-of-00014.bin:   4% 41.9M/990M [00:00<00:07, 131MB/s]
# pytorch_model-00011-of-00014.bin:   6% 62.9M/990M [00:00<00:06, 135MB/s]
# pytorch_model-00011-of-00014.bin:   8% 83.9M/990M [00:00<00:06, 136MB/s]
# pytorch_model-00011-of-00014.bin:  11% 105M/990M [00:00<00:07, 126MB/s]
# pytorch_model-00011-of-00014.bin:  13% 126M/990M [00:01<00:10, 82.4MB/s]
# pytorch_model-00011-of-00014.bin:  15% 147M/990M [00:01<00:08, 93.7MB/s]
# pytorch_model-00011-of-00014.bin:  17% 168M/990M [00:01<00:07, 103MB/s]
# pytorch_model-00011-of-00014.bin:  19% 189M/990M [00:01<00:07, 113MB/s]
# pytorch_model-00011-of-00014.bin:  21% 210M/990M [00:01<00:06, 122MB/s]
# pytorch_model-00011-of-00014.bin:  23% 231M/990M [00:01<00:05, 127MB/s]
# pytorch_model-00011-of-00014.bin:  25% 252M/990M [00:02<00:05, 132MB/s]
# pytorch_model-00011-of-00014.bin:  28% 273M/990M [00:02<00:05, 136MB/s]
# pytorch_model-00011-of-00014.bin:  30% 294M/990M [00:02<00:04, 140MB/s]
# pytorch_model-00011-of-00014.bin:  32% 315M/990M [00:02<00:04, 137MB/s]
# pytorch_model-00011-of-00014.bin:  34% 336M/990M [00:02<00:04, 140MB/s]
# pytorch_model-00011-of-00014.bin:  36% 357M/990M [00:02<00:04, 137MB/s]
# pytorch_model-00011-of-00014.bin:  38% 377M/990M [00:03<00:04, 139MB/s]
# pytorch_model-00011-of-00014.bin:  40% 398M/990M [00:03<00:04, 141MB/s]
# pytorch_model-00011-of-00014.bin:  42% 419M/990M [00:03<00:04, 142MB/s]
# pytorch_model-00011-of-00014.bin:  44% 440M/990M [00:03<00:03, 144MB/s]
# pytorch_model-00011-of-00014.bin:  47% 461M/990M [00:03<00:03, 145MB/s]
# pytorch_model-00011-of-00014.bin:  49% 482M/990M [00:03<00:03, 147MB/s]
# pytorch_model-00011-of-00014.bin:  51% 503M/990M [00:03<00:03, 132MB/s]
# pytorch_model-00011-of-00014.bin:  53% 524M/990M [00:04<00:03, 132MB/s]
# pytorch_model-00011-of-00014.bin:  55% 545M/990M [00:04<00:03, 133MB/s]
# pytorch_model-00011-of-00014.bin:  57% 566M/990M [00:04<00:03, 135MB/s]
# pytorch_model-00011-of-00014.bin:  59% 587M/990M [00:04<00:02, 139MB/s]
# pytorch_model-00011-of-00014.bin:  61% 608M/990M [00:04<00:02, 141MB/s]
# pytorch_model-00011-of-00014.bin:  64% 629M/990M [00:04<00:02, 143MB/s]
# pytorch_model-00011-of-00014.bin:  66% 650M/990M [00:04<00:02, 144MB/s]
# pytorch_model-00011-of-00014.bin:  68% 671M/990M [00:05<00:02, 144MB/s]
# pytorch_model-00011-of-00014.bin:  70% 692M/990M [00:05<00:02, 136MB/s]
# pytorch_model-00011-of-00014.bin:  72% 713M/990M [00:05<00:02, 137MB/s]
# pytorch_model-00011-of-00014.bin:  74% 734M/990M [00:05<00:01, 137MB/s]
# pytorch_model-00011-of-00014.bin:  76% 755M/990M [00:05<00:01, 138MB/s]
# pytorch_model-00011-of-00014.bin:  78% 776M/990M [00:05<00:01, 138MB/s]
# pytorch_model-00011-of-00014.bin:  81% 797M/990M [00:06<00:04, 48.2MB/s]
# pytorch_model-00011-of-00014.bin:  83% 818M/990M [00:07<00:02, 60.1MB/s]
# pytorch_model-00011-of-00014.bin:  85% 839M/990M [00:07<00:02, 71.4MB/s]
# pytorch_model-00011-of-00014.bin:  87% 860M/990M [00:07<00:01, 84.5MB/s]
# pytorch_model-00011-of-00014.bin:  89% 881M/990M [00:07<00:01, 93.1MB/s]
# pytorch_model-00011-of-00014.bin:  91% 902M/990M [00:08<00:02, 41.7MB/s]
# pytorch_model-00011-of-00014.bin:  93% 923M/990M [00:08<00:01, 52.8MB/s]
# pytorch_model-00011-of-00014.bin:  95% 944M/990M [00:09<00:00, 63.4MB/s]
# pytorch_model-00011-of-00014.bin:  97% 965M/990M [00:09<00:00, 75.6MB/s]
# pytorch_model-00011-of-00014.bin: 100% 990M/990M [00:09<00:00, 105MB/s]
# Downloading shards:  79% 11/14 [01:50<00:29,  9.89s/it]
# pytorch_model-00012-of-00014.bin:   0% 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00012-of-00014.bin:   2% 21.0M/967M [00:00<00:07, 127MB/s]
# pytorch_model-00012-of-00014.bin:   4% 41.9M/967M [00:00<00:08, 114MB/s]
# pytorch_model-00012-of-00014.bin:   7% 62.9M/967M [00:00<00:08, 108MB/s]
# pytorch_model-00012-of-00014.bin:   9% 83.9M/967M [00:00<00:07, 114MB/s]
# pytorch_model-00012-of-00014.bin:  11% 105M/967M [00:00<00:07, 118MB/s]
# pytorch_model-00012-of-00014.bin:  13% 126M/967M [00:01<00:06, 125MB/s]
# pytorch_model-00012-of-00014.bin:  15% 147M/967M [00:01<00:06, 128MB/s]
# pytorch_model-00012-of-00014.bin:  17% 168M/967M [00:01<00:05, 133MB/s]
# pytorch_model-00012-of-00014.bin:  20% 189M/967M [00:01<00:05, 137MB/s]
# pytorch_model-00012-of-00014.bin:  22% 210M/967M [00:01<00:05, 136MB/s]
# pytorch_model-00012-of-00014.bin:  24% 231M/967M [00:01<00:05, 132MB/s]
# pytorch_model-00012-of-00014.bin:  26% 252M/967M [00:01<00:05, 130MB/s]
# pytorch_model-00012-of-00014.bin:  28% 273M/967M [00:02<00:05, 127MB/s]
# pytorch_model-00012-of-00014.bin:  30% 294M/967M [00:02<00:05, 130MB/s]
# pytorch_model-00012-of-00014.bin:  33% 315M/967M [00:02<00:04, 131MB/s]
# pytorch_model-00012-of-00014.bin:  35% 336M/967M [00:02<00:04, 136MB/s]
# pytorch_model-00012-of-00014.bin:  37% 357M/967M [00:02<00:04, 139MB/s]
# pytorch_model-00012-of-00014.bin:  39% 377M/967M [00:02<00:04, 142MB/s]
# pytorch_model-00012-of-00014.bin:  41% 398M/967M [00:03<00:03, 144MB/s]
# pytorch_model-00012-of-00014.bin:  43% 419M/967M [00:03<00:03, 143MB/s]
# pytorch_model-00012-of-00014.bin:  46% 440M/967M [00:03<00:03, 134MB/s]
# pytorch_model-00012-of-00014.bin:  48% 461M/967M [00:03<00:03, 134MB/s]
# pytorch_model-00012-of-00014.bin:  50% 482M/967M [00:03<00:03, 137MB/s]
# pytorch_model-00012-of-00014.bin:  52% 503M/967M [00:03<00:03, 140MB/s]
# pytorch_model-00012-of-00014.bin:  54% 524M/967M [00:03<00:03, 142MB/s]
# pytorch_model-00012-of-00014.bin:  56% 545M/967M [00:04<00:02, 141MB/s]
# pytorch_model-00012-of-00014.bin:  59% 566M/967M [00:04<00:02, 142MB/s]
# pytorch_model-00012-of-00014.bin:  61% 587M/967M [00:04<00:02, 143MB/s]
# pytorch_model-00012-of-00014.bin:  63% 608M/967M [00:04<00:02, 144MB/s]
# pytorch_model-00012-of-00014.bin:  65% 629M/967M [00:04<00:02, 145MB/s]
# pytorch_model-00012-of-00014.bin:  67% 650M/967M [00:04<00:02, 136MB/s]
# pytorch_model-00012-of-00014.bin:  69% 671M/967M [00:04<00:02, 138MB/s]
# pytorch_model-00012-of-00014.bin:  72% 692M/967M [00:05<00:02, 134MB/s]
# pytorch_model-00012-of-00014.bin:  74% 713M/967M [00:05<00:01, 137MB/s]
# pytorch_model-00012-of-00014.bin:  76% 734M/967M [00:05<00:01, 140MB/s]
# pytorch_model-00012-of-00014.bin:  78% 755M/967M [00:05<00:01, 142MB/s]
# pytorch_model-00012-of-00014.bin:  80% 776M/967M [00:05<00:01, 143MB/s]
# pytorch_model-00012-of-00014.bin:  82% 797M/967M [00:05<00:01, 145MB/s]
# pytorch_model-00012-of-00014.bin:  85% 818M/967M [00:06<00:01, 145MB/s]
# pytorch_model-00012-of-00014.bin:  87% 839M/967M [00:06<00:00, 143MB/s]
# pytorch_model-00012-of-00014.bin:  89% 860M/967M [00:06<00:00, 138MB/s]
# pytorch_model-00012-of-00014.bin:  91% 881M/967M [00:06<00:00, 135MB/s]
# pytorch_model-00012-of-00014.bin:  93% 902M/967M [00:06<00:00, 138MB/s]
# pytorch_model-00012-of-00014.bin:  95% 923M/967M [00:06<00:00, 139MB/s]
# pytorch_model-00012-of-00014.bin:  98% 944M/967M [00:08<00:00, 38.5MB/s]
# pytorch_model-00012-of-00014.bin: 100% 967M/967M [00:09<00:00, 104MB/s]
# Downloading shards:  86% 12/14 [02:00<00:19,  9.78s/it]
# pytorch_model-00013-of-00014.bin:   0% 0.00/967M [00:00<?, ?B/s]
# pytorch_model-00013-of-00014.bin:   2% 21.0M/967M [00:00<00:06, 148MB/s]
# pytorch_model-00013-of-00014.bin:   4% 41.9M/967M [00:00<00:06, 146MB/s]
# pytorch_model-00013-of-00014.bin:   7% 62.9M/967M [00:00<00:06, 137MB/s]
# pytorch_model-00013-of-00014.bin:   9% 83.9M/967M [00:00<00:06, 141MB/s]
# pytorch_model-00013-of-00014.bin:  11% 105M/967M [00:00<00:06, 140MB/s]
# pytorch_model-00013-of-00014.bin:  13% 126M/967M [00:00<00:06, 140MB/s]
# pytorch_model-00013-of-00014.bin:  15% 147M/967M [00:01<00:05, 140MB/s]
# pytorch_model-00013-of-00014.bin:  17% 168M/967M [00:01<00:05, 139MB/s]
# pytorch_model-00013-of-00014.bin:  20% 189M/967M [00:01<00:05, 142MB/s]
# pytorch_model-00013-of-00014.bin:  22% 210M/967M [00:01<00:05, 143MB/s]
# pytorch_model-00013-of-00014.bin:  24% 231M/967M [00:01<00:05, 144MB/s]
# pytorch_model-00013-of-00014.bin:  26% 252M/967M [00:01<00:05, 141MB/s]
# pytorch_model-00013-of-00014.bin:  28% 273M/967M [00:01<00:04, 141MB/s]
# pytorch_model-00013-of-00014.bin:  30% 294M/967M [00:02<00:05, 133MB/s]
# pytorch_model-00013-of-00014.bin:  33% 315M/967M [00:02<00:05, 126MB/s]
# pytorch_model-00013-of-00014.bin:  35% 336M/967M [00:02<00:05, 122MB/s]
# pytorch_model-00013-of-00014.bin:  37% 357M/967M [00:02<00:05, 117MB/s]
# pytorch_model-00013-of-00014.bin:  39% 377M/967M [00:02<00:05, 114MB/s]
# pytorch_model-00013-of-00014.bin:  41% 398M/967M [00:04<00:17, 32.4MB/s]
# pytorch_model-00013-of-00014.bin:  43% 419M/967M [00:04<00:12, 42.3MB/s]
# pytorch_model-00013-of-00014.bin:  46% 440M/967M [00:04<00:09, 53.8MB/s]
# pytorch_model-00013-of-00014.bin:  48% 461M/967M [00:05<00:07, 66.0MB/s]
# pytorch_model-00013-of-00014.bin:  50% 482M/967M [00:05<00:06, 79.4MB/s]
# pytorch_model-00013-of-00014.bin:  52% 503M/967M [00:05<00:05, 90.9MB/s]
# pytorch_model-00013-of-00014.bin:  54% 524M/967M [00:05<00:04, 99.5MB/s]
# pytorch_model-00013-of-00014.bin:  56% 545M/967M [00:05<00:03, 107MB/s]
# pytorch_model-00013-of-00014.bin:  59% 566M/967M [00:05<00:03, 114MB/s]
# pytorch_model-00013-of-00014.bin:  61% 587M/967M [00:05<00:03, 120MB/s]
# pytorch_model-00013-of-00014.bin:  63% 608M/967M [00:06<00:02, 126MB/s]
# pytorch_model-00013-of-00014.bin:  65% 629M/967M [00:06<00:02, 132MB/s]
# pytorch_model-00013-of-00014.bin:  67% 650M/967M [00:06<00:02, 136MB/s]
# pytorch_model-00013-of-00014.bin:  69% 671M/967M [00:06<00:02, 138MB/s]
# pytorch_model-00013-of-00014.bin:  72% 692M/967M [00:06<00:01, 140MB/s]
# pytorch_model-00013-of-00014.bin:  74% 713M/967M [00:06<00:01, 139MB/s]
# pytorch_model-00013-of-00014.bin:  76% 734M/967M [00:07<00:01, 135MB/s]
# pytorch_model-00013-of-00014.bin:  78% 755M/967M [00:07<00:01, 129MB/s]
# pytorch_model-00013-of-00014.bin:  80% 776M/967M [00:07<00:01, 131MB/s]
# pytorch_model-00013-of-00014.bin:  82% 797M/967M [00:07<00:01, 131MB/s]
# pytorch_model-00013-of-00014.bin:  85% 818M/967M [00:09<00:04, 36.1MB/s]
# pytorch_model-00013-of-00014.bin:  86% 828M/967M [00:09<00:04, 32.0MB/s]
# pytorch_model-00013-of-00014.bin:  88% 849M/967M [00:09<00:02, 43.1MB/s]
# pytorch_model-00013-of-00014.bin:  90% 870M/967M [00:09<00:01, 55.8MB/s]
# pytorch_model-00013-of-00014.bin:  92% 891M/967M [00:10<00:01, 68.5MB/s]
# pytorch_model-00013-of-00014.bin:  94% 912M/967M [00:10<00:00, 82.4MB/s]
# pytorch_model-00013-of-00014.bin:  97% 933M/967M [00:10<00:00, 94.6MB/s]
# pytorch_model-00013-of-00014.bin: 100% 967M/967M [00:10<00:00, 91.4MB/s]
# Downloading shards:  93% 13/14 [02:11<00:10, 10.13s/it]
# pytorch_model-00014-of-00014.bin:   0% 0.00/847M [00:00<?, ?B/s]
# pytorch_model-00014-of-00014.bin:   2% 21.0M/847M [00:00<00:05, 147MB/s]
# pytorch_model-00014-of-00014.bin:   5% 41.9M/847M [00:00<00:10, 74.7MB/s]
# pytorch_model-00014-of-00014.bin:   7% 62.9M/847M [00:00<00:08, 96.6MB/s]
# pytorch_model-00014-of-00014.bin:  10% 83.9M/847M [00:00<00:06, 112MB/s]
# pytorch_model-00014-of-00014.bin:  12% 105M/847M [00:00<00:06, 115MB/s]
# pytorch_model-00014-of-00014.bin:  15% 126M/847M [00:01<00:05, 124MB/s]
# pytorch_model-00014-of-00014.bin:  17% 147M/847M [00:01<00:05, 129MB/s]
# pytorch_model-00014-of-00014.bin:  20% 168M/847M [00:01<00:05, 129MB/s]
# pytorch_model-00014-of-00014.bin:  22% 189M/847M [00:01<00:04, 135MB/s]
# pytorch_model-00014-of-00014.bin:  25% 210M/847M [00:01<00:04, 139MB/s]
# pytorch_model-00014-of-00014.bin:  27% 231M/847M [00:01<00:04, 140MB/s]
# pytorch_model-00014-of-00014.bin:  30% 252M/847M [00:02<00:04, 134MB/s]
# pytorch_model-00014-of-00014.bin:  32% 273M/847M [00:02<00:04, 136MB/s]
# pytorch_model-00014-of-00014.bin:  35% 294M/847M [00:02<00:04, 138MB/s]
# pytorch_model-00014-of-00014.bin:  37% 315M/847M [00:02<00:03, 140MB/s]
# pytorch_model-00014-of-00014.bin:  40% 336M/847M [00:02<00:03, 142MB/s]
# pytorch_model-00014-of-00014.bin:  42% 357M/847M [00:02<00:03, 144MB/s]
# pytorch_model-00014-of-00014.bin:  45% 377M/847M [00:02<00:03, 145MB/s]
# pytorch_model-00014-of-00014.bin:  47% 398M/847M [00:03<00:03, 146MB/s]
# pytorch_model-00014-of-00014.bin:  50% 419M/847M [00:03<00:02, 145MB/s]
# pytorch_model-00014-of-00014.bin:  52% 440M/847M [00:03<00:02, 140MB/s]
# pytorch_model-00014-of-00014.bin:  54% 461M/847M [00:03<00:02, 136MB/s]
# pytorch_model-00014-of-00014.bin:  57% 482M/847M [00:03<00:02, 136MB/s]
# pytorch_model-00014-of-00014.bin:  59% 503M/847M [00:03<00:02, 130MB/s]
# pytorch_model-00014-of-00014.bin:  62% 524M/847M [00:04<00:02, 128MB/s]
# pytorch_model-00014-of-00014.bin:  64% 545M/847M [00:04<00:02, 132MB/s]
# pytorch_model-00014-of-00014.bin:  67% 566M/847M [00:04<00:02, 131MB/s]
# pytorch_model-00014-of-00014.bin:  69% 587M/847M [00:04<00:01, 131MB/s]
# pytorch_model-00014-of-00014.bin:  72% 608M/847M [00:04<00:01, 132MB/s]
# pytorch_model-00014-of-00014.bin:  74% 629M/847M [00:04<00:01, 134MB/s]
# pytorch_model-00014-of-00014.bin:  77% 650M/847M [00:04<00:01, 128MB/s]
# pytorch_model-00014-of-00014.bin:  79% 671M/847M [00:05<00:01, 120MB/s]
# pytorch_model-00014-of-00014.bin:  82% 692M/847M [00:05<00:01, 117MB/s]
# pytorch_model-00014-of-00014.bin:  84% 713M/847M [00:05<00:01, 121MB/s]
# pytorch_model-00014-of-00014.bin:  87% 734M/847M [00:05<00:00, 123MB/s]
# pytorch_model-00014-of-00014.bin:  89% 755M/847M [00:05<00:00, 127MB/s]
# pytorch_model-00014-of-00014.bin:  92% 776M/847M [00:05<00:00, 130MB/s]
# pytorch_model-00014-of-00014.bin:  94% 797M/847M [00:06<00:00, 131MB/s]
# pytorch_model-00014-of-00014.bin:  97% 818M/847M [00:06<00:00, 126MB/s]
# pytorch_model-00014-of-00014.bin: 100% 847M/847M [00:06<00:00, 127MB/s]
# Downloading shards: 100% 14/14 [02:18<00:00,  9.86s/it]
# Loading checkpoint shards: 100% 14/14 [01:28<00:00,  6.35s/it]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# generation_config.json: 100% 132/132 [00:00<00:00, 570kB/s]
# > INFO    Using block size 1024
# Running tokenizer on train dataset:   0% 0/500 [00:00<?, ? examples/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1868 > 1024). Running this sequence through the model will result in indexing errors
# Running tokenizer on train dataset: 100% 500/500 [00:02<00:00, 214.87 examples/s]
# Grouping texts in chunks of 1024 (num_proc=4): 100% 500/500 [00:01<00:00, 371.11 examples/s]
# > INFO    creating trainer
#   0% 0/610 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.6385, 'learning_rate': 0.0001865209471766849, 'epoch': 0.8}
#  20% 122/610 [35:03<2:21:27, 17.39s/it]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.4315, 'learning_rate': 0.00015081967213114754, 'epoch': 1.6}
#  40% 245/610 [1:10:34<1:46:11, 17.46s/it]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.3739, 'learning_rate': 0.0001151183970856102, 'epoch': 2.4}
#  60% 368/610 [1:46:18<1:10:13, 17.41s/it]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.2644, 'learning_rate': 7.941712204007286e-05, 'epoch': 3.19}
# {'loss': 1.2285, 'learning_rate': 4.371584699453552e-05, 'epoch': 3.99}
#  80% 491/610 [2:21:55<34:30, 17.40s/it]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.1628, 'learning_rate': 8.014571948998179e-06, 'epoch': 4.79}
# {'train_runtime': 10582.609, 'train_samples_per_second': 0.232, 'train_steps_per_second': 0.058, 'train_loss': 1.341900628512023, 'epoch': 4.97}
# 100% 610/610 [2:56:22<00:00, 17.35s/it]
# > INFO    Finished training, saving model...
# > INFO    Pushing model to hub...
# adapter_model.bin:   0% 0.00/33.6M [00:00<?, ?B/s]
# adapter_model.safetensors:   0% 0.00/33.6M [00:00<?, ?B/s]
#
# adapter_model.safetensors:   0% 0.00/33.6M [00:00<?, ?B/s]
#
#
# optimizer.pt:   0% 0.00/67.2M [00:00<?, ?B/s]
#
#
#
# Upload 11 LFS files:   0% 0/11 [00:00<?, ?it/s]
#
#
#
#
# pytorch_model.bin:   0% 0.00/888 [00:00<?, ?B/s]
#
# adapter_model.safetensors:   0% 16.4k/33.6M [00:00<15:22, 36.4kB/s]
#
#
# optimizer.pt:   0% 16.4k/67.2M [00:00<32:11, 34.8kB/s]
#
#
#
#
# adapter_model.bin:   0% 16.4k/33.6M [00:00<16:58, 33.0kB/s]
# pytorch_model.bin: 100% 888/888 [00:00<00:00, 1.59kB/s]
#
#
# adapter_model.safetensors:   4% 1.38M/33.6M [00:00<00:10, 3.13MB/s]
#
#
# adapter_model.bin:   3% 934k/33.6M [00:00<00:16, 1.98MB/s]
# adapter_model.safetensors:   3% 999k/33.6M [00:00<00:15, 2.06MB/s]
#
# adapter_model.bin:  13% 4.49M/33.6M [00:00<00:02, 9.76MB/s]
#
#
# optimizer.pt:  10% 6.55M/67.2M [00:00<00:04, 14.0MB/s]
# adapter_model.safetensors:   9% 3.06M/33.6M [00:00<00:05, 5.83MB/s]
#
# adapter_model.bin:  23% 7.85M/33.6M [00:00<00:01, 15.0MB/s]
#
#
# optimizer.pt:  17% 11.5M/67.2M [00:00<00:02, 21.8MB/s]
# adapter_model.bin:  33% 11.2M/33.6M [00:00<00:01, 18.4MB/s]
#
#
#
#
# rng_state.pth:   0% 0.00/14.2k [00:00<?, ?B/s]
# adapter_model.safetensors:  17% 5.57M/33.6M [00:00<00:03, 8.51MB/s]
#
# adapter_model.safetensors:  48% 16.0M/33.6M [00:01<00:00, 20.4MB/s]
# rng_state.pth: 100% 14.2k/14.2k [00:00<00:00, 88.4kB/s]
#
#
#
# optimizer.pt:  24% 16.0M/67.2M [00:01<00:02, 17.8MB/s]
#
# adapter_model.safetensors:  71% 23.7M/33.6M [00:01<00:00, 30.5MB/s]
# adapter_model.safetensors:  33% 11.0M/33.6M [00:01<00:01, 15.0MB/s]
#
#
# optimizer.pt:  35% 23.3M/67.2M [00:01<00:01, 27.3MB/s]
#
#
#
#
# scheduler.pt:   0% 0.00/1.06k [00:00<?, ?B/s]
#
# adapter_model.bin:  48% 16.0M/33.6M [00:01<00:01, 15.4MB/s]
# scheduler.pt: 100% 1.06k/1.06k [00:00<00:00, 9.03kB/s]
#
#
#
# adapter_model.bin:  82% 27.5M/33.6M [00:01<00:00, 27.8MB/s]
#
#
# optimizer.pt:  52% 34.8M/67.2M [00:01<00:01, 30.0MB/s]
#
#
# optimizer.pt:  59% 39.6M/67.2M [00:01<00:00, 33.2MB/s]
#
#
#
#
# tokenizer.model:   0% 0.00/500k [00:00<?, ?B/s]
# adapter_model.safetensors: 100% 33.6M/33.6M [00:01<00:00, 18.1MB/s]
#
# adapter_model.bin:  95% 32.0M/33.6M [00:01<00:00, 21.4MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 1.45MB/s]
#
#
#
# optimizer.pt:  71% 48.0M/67.2M [00:02<00:00, 28.5MB/s]
#
# training_args.bin:   0% 0.00/4.54k [00:00<?, ?B/s]
# adapter_model.safetensors:  95% 32.0M/33.6M [00:02<00:00, 23.4MB/s]
#
#
# optimizer.pt:  83% 55.6M/67.2M [00:02<00:00, 35.5MB/s]
#
#
#
#
# tokenizer.model:   0% 0.00/500k [00:00<?, ?B/s]
#
#
# training_args.bin: 100% 4.54k/4.54k [00:00<00:00, 25.7kB/s]
# adapter_model.bin: 100% 33.6M/33.6M [00:02<00:00, 14.5MB/s]
# adapter_model.safetensors: 100% 33.6M/33.6M [00:02<00:00, 13.5MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 1.28MB/s]
# training_args.bin: 100% 4.54k/4.54k [00:00<00:00, 31.6kB/s]
#
#
#
#
# optimizer.pt: 100% 67.2M/67.2M [00:02<00:00, 23.6MB/s]
#
#
#
#
# Upload 11 LFS files: 100% 11/11 [00:03<00:00,  3.33it/s]
